# %%
import pandas as pd
import networkx as nx

path = 'Data/'

# %%
import pickle5 as pickle
import time

# %%
df = pd.read_parquet('{}file-name_query03-05.parquet'.format(path))
df
# Out:
#        Unnamed: 0                             doi             bioActivity  \
# 0               0  10.1016/j.biortech.2010.01.041  Inhibition of Protease
# 1               0  10.1016/j.biortech.2010.01.041  Inhibition of Protease
# 2               0  10.1016/j.biortech.2010.01.041  Inhibition of Protease
# 3               0  10.1016/j.biortech.2010.01.041  Inhibition of Protease
# 4               0  10.1016/j.biortech.2010.01.041  Inhibition of Protease
# ...           ...                             ...                     ...
# 11615        2386   10.1016/S0031-9422(00)94671-5
# 11616        2387   10.1016/S0031-9422(00)80444-6
# 11617        2388             10.1021/np50032a021
# 11618        2389   10.1016/S0031-9422(00)83467-6
# 11619        2390    10.1016/0031-9422(80)83208-0
#
#                        collectionSpecie collectionSite  \
# 0      Piper crassinervium (Piperaceae)  Araraquara/SP
# 1      Piper crassinervium (Piperaceae)  Araraquara/SP
# 2      Piper crassinervium (Piperaceae)  Araraquara/SP
# 3      Piper crassinervium (Piperaceae)  Araraquara/SP
# 4      Piper crassinervium (Piperaceae)  Araraquara/SP
# ...                                 ...            ...
# 11615
# 11616
# 11617
# 11618
# 11619
#
#                   collectionType                             molType  \
# 0      Biotransformation Product  http://nubbe.db/AromaticDerivative
# 1      Biotransformation Product  http://nubbe.db/AromaticDerivative
# 2      Biotransformation Product  http://nubbe.db/AromaticDerivative
# 3      Biotransformation Product  http://nubbe.db/AromaticDerivative
# 4      Biotransformation Product  http://nubbe.db/AromaticDerivative
# ...                          ...                                 ...
# 11615
# 11616
# 11617
# 11618
# 11619
#
#       molecularMass monoisotropicMass        cLogP         tpsa  \
# 0        290,354187       290,1517944  4,660999775  66,76100159
# 1        290,354187       290,1517944  4,660999775  66,76100159
# 2        290,354187       290,1517944  4,660999775  66,76100159
# 3        290,354187       290,1517944  4,660999775  66,76100159
# 4        290,354187       290,1517944  4,660999775  66,76100159
# ...             ...               ...          ...          ...
# 11615
# 11616
# 11617
# 11618
# 11619
#
#       numberOfLipinskiViolations numberOfH_bondAcceptors numberOfH_bondDonors  \
# 0                            0.0                     4.0                  2.0
# 1                            0.0                     4.0                  2.0
# 2                            0.0                     4.0                  2.0
# 3                            0.0                     4.0                  2.0
# 4                            0.0                     4.0                  2.0
# ...                          ...                     ...                  ...
# 11615
# 11616
# 11617
# 11618
# 11619
#
#       numberOfRotableBonds molecularVolume  \
# 0                      7.0     282,9689941
# 1                      7.0     282,9689941
# 2                      7.0     282,9689941
# 3                      7.0     282,9689941
# 4                      7.0     282,9689941
# ...                    ...             ...
# 11615
# 11616
# 11617
# 11618
# 11619
#
#                                              smile  \
# 0      O=C(OC/C=C(C)/CC/C=C(C)/C)C1=CC(O)=C(O)C=C1
# 1      O=C(OC/C=C(C)/CC/C=C(C)/C)C1=CC(O)=C(O)C=C1
# 2      O=C(OC/C=C(C)/CC/C=C(C)/C)C1=CC(O)=C(O)C=C1
# 3      O=C(OC/C=C(C)/CC/C=C(C)/C)C1=CC(O)=C(O)C=C1
# 4      O=C(OC/C=C(C)/CC/C=C(C)/C)C1=CC(O)=C(O)C=C1
# ...                                            ...
# 11615
# 11616
# 11617
# 11618
# 11619
#
#                                           name  \
# 0      3,4-dihydroxybenzoic acid geranyl ester
# 1      3,4-dihydroxybenzoic acid geranyl ester
# 2      3,4-dihydroxybenzoic acid geranyl ester
# 3      3,4-dihydroxybenzoic acid geranyl ester
# 4      3,4-dihydroxybenzoic acid geranyl ester
# ...                                        ...
# 11615
# 11616
# 11617
# 11618
# 11619
#
#                                 file_name
# 0      10.1016@j.biortech.2010.01.041.pdf
# 1      10.1016@j.biortech.2010.01.041.pdf
# 2      10.1016@j.biortech.2010.01.041.pdf
# 3      10.1016@j.biortech.2010.01.041.pdf
# 4      10.1016@j.biortech.2010.01.041.pdf
# ...                                   ...
# 11615   10.1016@S0031-9422(00)94671-5.pdf
# 11616   10.1016@S0031-9422(00)80444-6.pdf
# 11617             10.1021@np50032a021.pdf
# 11618   10.1016@S0031-9422(00)83467-6.pdf
# 11619    10.1016@0031-9422(80)83208-0.pdf
#
# [11620 rows x 19 columns]

# %%
texts_df = pd.read_parquet('{}topics03-05.parquet'.format(path))
texts_df
# Out:
#                                  doi                            file_name  \
# 0     10.1016/j.biortech.2010.01.041   10.1016@j.biortech.2010.01.041.pdf
# 1    10.1590/S0100-40422010000200017  10.1590@S0100-40422010000200017.pdf
# 2    10.1590/S0103-50532006000500017  10.1590@S0103-50532006000500017.pdf
# 3                    10.1002/pca.818                  10.1002@pca.818.pdf
# 4                     10.1002/ps.478                   10.1002@ps.478.pdf
# ..                               ...                                  ...
# 381    10.1016/S0031-9422(00)94671-5    10.1016@S0031-9422(00)94671-5.pdf
# 382    10.1016/S0031-9422(00)80444-6    10.1016@S0031-9422(00)80444-6.pdf
# 383              10.1021/np50032a021              10.1021@np50032a021.pdf
# 384    10.1016/S0031-9422(00)83467-6    10.1016@S0031-9422(00)83467-6.pdf
# 385     10.1016/0031-9422(80)83208-0     10.1016@0031-9422(80)83208-0.pdf
#
#                                                   text  \
# 0    Geranylation of benzoic acid derivatives by en...
# 1    Quim. Nova, Vol. 33, No. 2, 321-323, 2010 Arti...
# 2    J. Braz. Chem. Soc., Vol. 17, No. 5, 929-934, ...
# 3    FLAVONOID GLYCOSIDES AND STYRYLPYRONES FROM CR...
# 4    Biological activity of astilbin from ���������...
# ..                                                 ...
# 381  Short Reports  1671  Dichrographe Mark III, R....
# 382  Phytochemrstry,  Vol. 23, No 6, pp. 1X33-1296,...
# 383  Journal of Natural Products  Vol. 47. No. 2. p...
# 384  Phytockmistry,  Vol. 23, No. 8, pp. 1677-1679,...
# 385  Phytochemistry, 1980, Vol. 19, pp. 474-476. © ...
#
#                                                phrases  \
# 0    [Geranylation of benzoic acid derivatives by e...
# 1    [Quim. Nova, Vol. 33, No. 2, 321-323, 2010 Art...
# 2    [J. Braz. Chem. Soc., Vol. 17, No. 5, 929-934,...
# 3    [FLAVONOID GLYCOSIDES AND STYRYLPYRONES FROM C...
# 4    [Biological activity of astilbin from ��������...
# ..                                                 ...
# 381  [Short Reports  1671  Dichrographe Mark III, R...
# 382  [Phytochemrstry,  Vol. 23, No 6, pp. 1X33-1296...
# 383  [Journal of Natural Products  Vol. 47. No. 2. ...
# 384  [Phytockmistry,  Vol. 23, No. 8, pp. 1677-1679...
# 385  [Phytochemistry, 1980, Vol. 19, pp. 474-476. ©...
#
#                                                 topics
# 0    [128, 132, 7, 13, 36, 42, 55, 79, 84, 91, 117,...
# 1                                   [19, 29, 116, 125]
# 2          [3, 13, 145, 144, 36, 42, 54, 56, 124, 125]
# 3    [135, 11, 13, 14, 141, 46, 65, 81, 116, 120, 1...
# 4    [1, 131, 129, 7, 8, 137, 11, 140, 142, 16, 144...
# ..                                                 ...
# 381                                [129, 141, 84, 103]
# 382                [139, 145, 144, 36, 40, 42, 54, 56]
# 383                                          [79, 103]
# 384                   [135, 145, 19, 36, 83, 103, 124]
# 385     [145, 17, 20, 31, 45, 52, 60, 80, 84, 97, 125]
#
# [386 rows x 5 columns]

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import sent_tokenize

def create_phrases_from_sentences(text):
    # Tokenize text into sentences
    sentences = sent_tokenize(text)
    
    phrases = []
    current_phrase = []
    current_length = 0
    
    for sentence in sentences:
        sentence_length = len(sentence)
        
        # If single sentence exceeds 512, keep it as a whole phrase
        if sentence_length > 512:
            if current_phrase:  # Store any accumulated phrases first
                phrases.append(' '.join(current_phrase))
                current_phrase = []
                current_length = 0
            phrases.append(sentence)
            continue
            
        # Check if adding this sentence would exceed 512 characters
        if current_length + sentence_length + 1 <= 512:  # +1 for space
            current_phrase.append(sentence)
            current_length += sentence_length + 1
        else:
            # Store current phrase and start new one
            if current_phrase:
                phrases.append(' '.join(current_phrase))
            current_phrase = [sentence]
            current_length = sentence_length
    
    # Add any remaining phrases
    if current_phrase:
        phrases.append(' '.join(current_phrase))
    
    return phrases

# Apply the function to create phrases_2 column
texts_df['phrases_2'] = texts_df['text'].apply(create_phrases_from_sentences)
texts_df
# Out:
# [nltk_data] Downloading package punkt to /home/dfsbharath/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                  doi                            file_name  \
# 0     10.1016/j.biortech.2010.01.041   10.1016@j.biortech.2010.01.041.pdf
# 1    10.1590/S0100-40422010000200017  10.1590@S0100-40422010000200017.pdf
# 2    10.1590/S0103-50532006000500017  10.1590@S0103-50532006000500017.pdf
# 3                    10.1002/pca.818                  10.1002@pca.818.pdf
# 4                     10.1002/ps.478                   10.1002@ps.478.pdf
# ..                               ...                                  ...
# 381    10.1016/S0031-9422(00)94671-5    10.1016@S0031-9422(00)94671-5.pdf
# 382    10.1016/S0031-9422(00)80444-6    10.1016@S0031-9422(00)80444-6.pdf
# 383              10.1021/np50032a021              10.1021@np50032a021.pdf
# 384    10.1016/S0031-9422(00)83467-6    10.1016@S0031-9422(00)83467-6.pdf
# 385     10.1016/0031-9422(80)83208-0     10.1016@0031-9422(80)83208-0.pdf
#
#                                                   text  \
# 0    Geranylation of benzoic acid derivatives by en...
# 1    Quim. Nova, Vol. 33, No. 2, 321-323, 2010 Arti...
# 2    J. Braz. Chem. Soc., Vol. 17, No. 5, 929-934, ...
# 3    FLAVONOID GLYCOSIDES AND STYRYLPYRONES FROM CR...
# 4    Biological activity of astilbin from ���������...
# ..                                                 ...
# 381  Short Reports  1671  Dichrographe Mark III, R....
# 382  Phytochemrstry,  Vol. 23, No 6, pp. 1X33-1296,...
# 383  Journal of Natural Products  Vol. 47. No. 2. p...
# 384  Phytockmistry,  Vol. 23, No. 8, pp. 1677-1679,...
# 385  Phytochemistry, 1980, Vol. 19, pp. 474-476. © ...
#
#                                                phrases  \
# 0    [Geranylation of benzoic acid derivatives by e...
# 1    [Quim. Nova, Vol. 33, No. 2, 321-323, 2010 Art...
# 2    [J. Braz. Chem. Soc., Vol. 17, No. 5, 929-934,...
# 3    [FLAVONOID GLYCOSIDES AND STYRYLPYRONES FROM C...
# 4    [Biological activity of astilbin from ��������...
# ..                                                 ...
# 381  [Short Reports  1671  Dichrographe Mark III, R...
# 382  [Phytochemrstry,  Vol. 23, No 6, pp. 1X33-1296...
# 383  [Journal of Natural Products  Vol. 47. No. 2. ...
# 384  [Phytockmistry,  Vol. 23, No. 8, pp. 1677-1679...
# 385  [Phytochemistry, 1980, Vol. 19, pp. 474-476. ©...
#
#                                                 topics  \
# 0    [128, 132, 7, 13, 36, 42, 55, 79, 84, 91, 117,...
# 1                                   [19, 29, 116, 125]
# 2          [3, 13, 145, 144, 36, 42, 54, 56, 124, 125]
# 3    [135, 11, 13, 14, 141, 46, 65, 81, 116, 120, 1...
# 4    [1, 131, 129, 7, 8, 137, 11, 140, 142, 16, 144...
# ..                                                 ...
# 381                                [129, 141, 84, 103]
# 382                [139, 145, 144, 36, 40, 42, 54, 56]
# 383                                          [79, 103]
# 384                   [135, 145, 19, 36, 83, 103, 124]
# 385     [145, 17, 20, 31, 45, 52, 60, 80, 84, 97, 125]
#
#                                              phrases_2
# 0    [Geranylation of benzoic acid derivatives by e...
# 1    [Quim. Nova, Vol. 33, No., 2, 321-323, 2010 Ar...
# 2    [J. Braz. Chem. Soc., Vol. 17, No. 5, 929-934,...
# 3    [FLAVONOID GLYCOSIDES AND STYRYLPYRONES FROM C...
# 4    [Biological activity of astilbin from ��������...
# ..                                                 ...
# 381  [Short Reports  1671  Dichrographe Mark III, R...
# 382  [Phytochemrstry,  Vol. 23, No 6, pp. 1X33-1296...
# 383  [Journal of Natural Products  Vol. 47. No. 2. ...
# 384  [Phytockmistry,  Vol. 23, No. 8, pp. 1677-1679...
# 385  [Phytochemistry, 1980, Vol. 19, pp. 474-476. ©...
#
# [386 rows x 6 columns]

# %%
from sentence_transformers import SentenceTransformer, LoggingHandler
import numpy as np
from tqdm.notebook import tqdm
import logging

#### Just some code to print debug information to stdout
np.set_printoptions(threshold=100)

logging.basicConfig(format='%(asctime)s - %(message)s',
                    datefmt='%Y-%m-%d %H:%M:%S',
                    level=logging.INFO,
                    handlers=[LoggingHandler()])

# Load Sentence model (based on BERT) from URL
model = SentenceTransformer('sentence-transformers/distiluse-base-multilingual-cased-v2')

def model_encode(model):
    embeddings = []
    for _, phrases in tqdm(texts_df['phrases'].items()):
        embedding = np.zeros(512)
        for phrase in phrases:
            embedding += model.encode(phrase, show_progress_bar=False)
        embeddings.append(embedding)
    return embeddings

texts_df['embedding'] = model_encode(model)
texts_df
# Out:
# 2026-04-22 19:28:10 - Load pretrained SentenceTransformer: sentence-transformers/distiluse-base-multilingual-cased-v2
# 2026-04-22 19:28:12 - Use pytorch device: cuda
# 0it [00:00, ?it/s]
#                                  doi                            file_name  \
# 0     10.1016/j.biortech.2010.01.041   10.1016@j.biortech.2010.01.041.pdf
# 1    10.1590/S0100-40422010000200017  10.1590@S0100-40422010000200017.pdf
# 2    10.1590/S0103-50532006000500017  10.1590@S0103-50532006000500017.pdf
# 3                    10.1002/pca.818                  10.1002@pca.818.pdf
# 4                     10.1002/ps.478                   10.1002@ps.478.pdf
# ..                               ...                                  ...
# 381    10.1016/S0031-9422(00)94671-5    10.1016@S0031-9422(00)94671-5.pdf
# 382    10.1016/S0031-9422(00)80444-6    10.1016@S0031-9422(00)80444-6.pdf
# 383              10.1021/np50032a021              10.1021@np50032a021.pdf
# 384    10.1016/S0031-9422(00)83467-6    10.1016@S0031-9422(00)83467-6.pdf
# 385     10.1016/0031-9422(80)83208-0     10.1016@0031-9422(80)83208-0.pdf
#
#                                                   text  \
# 0    Geranylation of benzoic acid derivatives by en...
# 1    Quim. Nova, Vol. 33, No. 2, 321-323, 2010 Arti...
# 2    J. Braz. Chem. Soc., Vol. 17, No. 5, 929-934, ...
# 3    FLAVONOID GLYCOSIDES AND STYRYLPYRONES FROM CR...
# 4    Biological activity of astilbin from ���������...
# ..                                                 ...
# 381  Short Reports  1671  Dichrographe Mark III, R....
# 382  Phytochemrstry,  Vol. 23, No 6, pp. 1X33-1296,...
# 383  Journal of Natural Products  Vol. 47. No. 2. p...
# 384  Phytockmistry,  Vol. 23, No. 8, pp. 1677-1679,...
# 385  Phytochemistry, 1980, Vol. 19, pp. 474-476. © ...
#
#                                                phrases  \
# 0    [Geranylation of benzoic acid derivatives by e...
# 1    [Quim. Nova, Vol. 33, No. 2, 321-323, 2010 Art...
# 2    [J. Braz. Chem. Soc., Vol. 17, No. 5, 929-934,...
# 3    [FLAVONOID GLYCOSIDES AND STYRYLPYRONES FROM C...
# 4    [Biological activity of astilbin from ��������...
# ..                                                 ...
# 381  [Short Reports  1671  Dichrographe Mark III, R...
# 382  [Phytochemrstry,  Vol. 23, No 6, pp. 1X33-1296...
# 383  [Journal of Natural Products  Vol. 47. No. 2. ...
# 384  [Phytockmistry,  Vol. 23, No. 8, pp. 1677-1679...
# 385  [Phytochemistry, 1980, Vol. 19, pp. 474-476. ©...
#
#                                                 topics  \
# 0    [128, 132, 7, 13, 36, 42, 55, 79, 84, 91, 117,...
# 1                                   [19, 29, 116, 125]
# 2          [3, 13, 145, 144, 36, 42, 54, 56, 124, 125]
# 3    [135, 11, 13, 14, 141, 46, 65, 81, 116, 120, 1...
# 4    [1, 131, 129, 7, 8, 137, 11, 140, 142, 16, 144...
# ..                                                 ...
# 381                                [129, 141, 84, 103]
# 382                [139, 145, 144, 36, 40, 42, 54, 56]
# 383                                          [79, 103]
# 384                   [135, 145, 19, 36, 83, 103, 124]
# 385     [145, 17, 20, 31, 45, 52, 60, 80, 84, 97, 125]
#
#                                              phrases_2  \
# 0    [Geranylation of benzoic acid derivatives by e...
# 1    [Quim. Nova, Vol. 33, No., 2, 321-323, 2010 Ar...
# 2    [J. Braz. Chem. Soc., Vol. 17, No. 5, 929-934,...
# 3    [FLAVONOID GLYCOSIDES AND STYRYLPYRONES FROM C...
# 4    [Biological activity of astilbin from ��������...
# ..                                                 ...
# 381  [Short Reports  1671  Dichrographe Mark III, R...
# 382  [Phytochemrstry,  Vol. 23, No 6, pp. 1X33-1296...
# 383  [Journal of Natural Products  Vol. 47. No. 2. ...
# 384  [Phytockmistry,  Vol. 23, No. 8, pp. 1677-1679...
# 385  [Phytochemistry, 1980, Vol. 19, pp. 474-476. ©...
#
#                                              embedding
# 0    [-0.8950120258668903, 0.6137961038039066, 0.44...
# 1    [0.0405009975656867, 0.44275646680034697, -0.0...
# 2    [-0.31248260155553, 0.4514679341809824, -0.311...
# 3    [-0.13642807520227507, 0.9625891325995326, -0....
# 4    [0.3284127317601815, -0.26284066238440573, -1....
# ..                                                 ...
# 381  [-0.21970843500457704, 0.33494950411841273, 0....
# 382  [-0.21785177156561986, 0.9152516985777766, -0....
# 383  [-0.30958136823028326, 0.12105274572968483, -0...
# 384  [-0.2592933098785579, 0.36754319537431, -0.222...
# 385  [-0.48299783864058554, 0.4926578173181042, -0....
#
# [386 rows x 7 columns]

# %%
texts_df.to_parquet('{}topics_embeddings.parquet'.format(path))

# %%
import pandas as pd
import numpy as np
import re






def find_element_positions(phrase, element):
    """Find character and word positions of an element in a phrase."""
    if not isinstance(element, str) or pd.isna(element) or not element.strip():
        return None
    
    # Convert both to lowercase for case-insensitive matching
    phrase_lower = phrase.lower()
    element_lower = element.lower()
    
    # Find character position
    char_pos = phrase_lower.find(element_lower)
    if char_pos == -1:
        return None
        
    # Find word position
    words = phrase[:char_pos].split()
    start_word_pos = len(words)
    end_word_pos = start_word_pos + len(element_lower.split())
    

    return {
        'surface_char_pos': np.array([char_pos, char_pos + len(element_lower)]),
        'surface_form': element.lower(),
        'surface_word_pos': np.array([start_word_pos, end_word_pos]),
        'types': np.array([], dtype=object),
        'uri': element.lower()
    }

def process_entities(df, texts_df):
    # Merge the dataframes on doi
    merged_df = pd.merge(texts_df, df, on='doi', how='left')
    
    # Columns to check for entities
    entity_columns = ['bioActivity', 'collectionSpecie', 'collectionSite', 
                     'collectionType', 'name']
    
    data = []
    data_2 = []
    
    # Global counter for unique phrase IDs
    global_phrase_idx = 0
    
    # Iterate through each row
    for idx, row in merged_df.iterrows():
        if not isinstance(row['phrases_2'], list):
            continue
            
        # Process each phrase
        for phrase in row['phrases_2']:
            if not isinstance(phrase, str):
                continue
                
            phrase = re.sub("(\\d|\\W)+"," ",phrase)
            phrase = phrase.strip()

            data_2.append({
                'label': global_phrase_idx,
                'text_a': phrase.lower()
            })
                
            # Check each entity column
            for col in entity_columns:
                if col=='name':
                    if ';' in row[col]:
                        temp_element = row[col].split(';')
                        for te in temp_element:
                            te = re.sub("(\\d|\\W)+"," ",te)
                            te = te.strip()
                            positions = find_element_positions(phrase, te)

                    else:
                        element = row[col]
                        element = re.sub("(\\d|\\W)+"," ",element)
                        element = element.strip()
                        positions = find_element_positions(phrase, element)

                else:
                            
                    element = row[col]
                    element = re.sub("(\\d|\\W)+"," ",element)
                    element = element.strip()
                    positions = find_element_positions(phrase, element)
                
                if positions:
                    data.append({
                        'source_id': global_phrase_idx,
                        'entity_data': positions,
                        'uri': element.lower()
                    })
            
            # Increment the global counter after processing each phrase
            global_phrase_idx += 1
    
    return data, data_2

# Example usage:
data, data_2 = process_entities(df, texts_df)

# %%
data
# Out:
# [{'source_id': 0,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 1,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 2,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 18,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 67,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 114,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 115,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 116,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 132,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 181,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 228,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 229,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 230,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 246,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 295,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 342,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 343,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 344,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 360,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 409,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 456,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 457,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 458,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 474,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 523,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 570,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 571,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 572,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 588,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 637,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 684,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 685,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 686,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 702,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 751,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 798,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 799,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 800,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 816,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 865,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 912,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 913,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 914,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 930,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 979,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 1026,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 1027,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 1028,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 1044,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 1093,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 1140,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 1141,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 1142,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 1158,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 1207,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 1254,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 1255,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 1256,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 1272,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 1321,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 1368,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 1369,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 1370,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 1386,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 1435,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 1482,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 1483,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 1484,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 1500,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 1549,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 1596,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 1597,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 1598,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 1614,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 1663,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 1710,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 1711,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 1712,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 1728,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 1777,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 1824,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 1825,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 1826,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 1842,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 1891,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 1938,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 1939,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 1940,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 1956,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 2005,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 2052,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 2053,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 2054,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 2059,
#   'entity_data': {'surface_char_pos': array([119, 128]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([15, 16]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2070,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 2107,
#   'entity_data': {'surface_char_pos': array([798, 807]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([108, 109]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2108,
#   'entity_data': {'surface_char_pos': array([320, 329]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([44, 45]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2110,
#   'entity_data': {'surface_char_pos': array([718, 727]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([97, 98]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2119,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 2129,
#   'entity_data': {'surface_char_pos': array([684, 693]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([88, 89]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2140,
#   'entity_data': {'surface_char_pos': array([301, 310]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([47, 48]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2143,
#   'entity_data': {'surface_char_pos': array([105, 114]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([17, 18]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2166,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 2167,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 2168,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 2173,
#   'entity_data': {'surface_char_pos': array([119, 128]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([15, 16]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2184,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 2221,
#   'entity_data': {'surface_char_pos': array([798, 807]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([108, 109]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2222,
#   'entity_data': {'surface_char_pos': array([320, 329]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([44, 45]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2224,
#   'entity_data': {'surface_char_pos': array([718, 727]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([97, 98]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2233,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 2243,
#   'entity_data': {'surface_char_pos': array([684, 693]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([88, 89]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2254,
#   'entity_data': {'surface_char_pos': array([301, 310]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([47, 48]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2257,
#   'entity_data': {'surface_char_pos': array([105, 114]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([17, 18]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2280,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 2281,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 2282,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 2287,
#   'entity_data': {'surface_char_pos': array([119, 128]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([15, 16]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2298,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 2335,
#   'entity_data': {'surface_char_pos': array([798, 807]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([108, 109]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2336,
#   'entity_data': {'surface_char_pos': array([320, 329]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([44, 45]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2338,
#   'entity_data': {'surface_char_pos': array([718, 727]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([97, 98]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2347,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 2357,
#   'entity_data': {'surface_char_pos': array([684, 693]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([88, 89]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2368,
#   'entity_data': {'surface_char_pos': array([301, 310]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([47, 48]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2371,
#   'entity_data': {'surface_char_pos': array([105, 114]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([17, 18]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2394,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 2395,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 2396,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 2401,
#   'entity_data': {'surface_char_pos': array([119, 128]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([15, 16]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2412,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 2449,
#   'entity_data': {'surface_char_pos': array([798, 807]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([108, 109]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2450,
#   'entity_data': {'surface_char_pos': array([320, 329]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([44, 45]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2452,
#   'entity_data': {'surface_char_pos': array([718, 727]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([97, 98]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2461,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 2471,
#   'entity_data': {'surface_char_pos': array([684, 693]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([88, 89]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2482,
#   'entity_data': {'surface_char_pos': array([301, 310]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([47, 48]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2485,
#   'entity_data': {'surface_char_pos': array([105, 114]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([17, 18]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2508,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 2509,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 2510,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 2515,
#   'entity_data': {'surface_char_pos': array([119, 128]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([15, 16]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2526,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 2563,
#   'entity_data': {'surface_char_pos': array([798, 807]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([108, 109]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2564,
#   'entity_data': {'surface_char_pos': array([320, 329]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([44, 45]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2566,
#   'entity_data': {'surface_char_pos': array([718, 727]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([97, 98]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2575,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 2585,
#   'entity_data': {'surface_char_pos': array([684, 693]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([88, 89]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2596,
#   'entity_data': {'surface_char_pos': array([301, 310]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([47, 48]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2599,
#   'entity_data': {'surface_char_pos': array([105, 114]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([17, 18]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2622,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 2623,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 2624,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 2629,
#   'entity_data': {'surface_char_pos': array([119, 128]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([15, 16]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2640,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 2677,
#   'entity_data': {'surface_char_pos': array([798, 807]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([108, 109]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2678,
#   'entity_data': {'surface_char_pos': array([320, 329]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([44, 45]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2680,
#   'entity_data': {'surface_char_pos': array([718, 727]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([97, 98]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2689,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 2699,
#   'entity_data': {'surface_char_pos': array([684, 693]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([88, 89]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2710,
#   'entity_data': {'surface_char_pos': array([301, 310]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([47, 48]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2713,
#   'entity_data': {'surface_char_pos': array([105, 114]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([17, 18]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2736,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 2737,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 2738,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 2743,
#   'entity_data': {'surface_char_pos': array([119, 128]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([15, 16]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2754,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 2791,
#   'entity_data': {'surface_char_pos': array([798, 807]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([108, 109]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2792,
#   'entity_data': {'surface_char_pos': array([320, 329]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([44, 45]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2794,
#   'entity_data': {'surface_char_pos': array([718, 727]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([97, 98]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2803,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 2813,
#   'entity_data': {'surface_char_pos': array([684, 693]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([88, 89]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2824,
#   'entity_data': {'surface_char_pos': array([301, 310]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([47, 48]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2827,
#   'entity_data': {'surface_char_pos': array([105, 114]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([17, 18]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2850,
#   'entity_data': {'surface_char_pos': array([68, 98]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([ 9, 12]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 2851,
#   'entity_data': {'surface_char_pos': array([ 0, 13]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([0, 2]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 2852,
#   'entity_data': {'surface_char_pos': array([176, 206]),
#    'surface_form': 'piper crassinervium piperaceae',
#    'surface_word_pos': array([33, 36]),
#    'types': array([], dtype=object),
#    'uri': 'piper crassinervium piperaceae'},
#   'uri': 'piper crassinervium piperaceae'},
#  {'source_id': 2857,
#   'entity_data': {'surface_char_pos': array([119, 128]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([15, 16]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2868,
#   'entity_data': {'surface_char_pos': array([464, 477]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([71, 73]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 2905,
#   'entity_data': {'surface_char_pos': array([798, 807]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([108, 109]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2906,
#   'entity_data': {'surface_char_pos': array([320, 329]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([44, 45]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2908,
#   'entity_data': {'surface_char_pos': array([718, 727]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([97, 98]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2917,
#   'entity_data': {'surface_char_pos': array([28, 53]),
#    'surface_form': 'biotransformation product',
#    'surface_word_pos': array([4, 6]),
#    'types': array([], dtype=object),
#    'uri': 'biotransformation product'},
#   'uri': 'biotransformation product'},
#  {'source_id': 2927,
#   'entity_data': {'surface_char_pos': array([684, 693]),
#    'surface_form': 'antiviral',
#    'surface_word_pos': array([88, 89]),
#    'types': array([], dtype=object),
#    'uri': 'antiviral'},
#   'uri': 'antiviral'},
#  {'source_id': 2938,
#   'entity_data': {'surface_char_pos': array([301, 310]),
# ...
#    'surface_form': 'fagaramide',
#    'surface_word_pos': array([15, 16]),
#    'types': array([], dtype=object),
#    'uri': 'fagaramide'},
#   'uri': 'fagaramide'},
#  {'source_id': 10548,
#   'entity_data': {'surface_char_pos': array([ 4, 14]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([1, 2]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10549,
#   'entity_data': {'surface_char_pos': array([189, 199]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([33, 34]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10551,
#   'entity_data': {'surface_char_pos': array([151, 161]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([21, 22]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10554,
#   'entity_data': {'surface_char_pos': array([305, 318]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([57, 59]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 10556,
#   'entity_data': {'surface_char_pos': array([ 0, 10]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([0, 1]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10560,
#   'entity_data': {'surface_char_pos': array([34, 44]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([6, 7]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10561,
#   'entity_data': {'surface_char_pos': array([ 6, 16]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([1, 2]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10569,
#   'entity_data': {'surface_char_pos': array([387, 397]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([78, 79]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10574,
#   'entity_data': {'surface_char_pos': array([104, 114]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([25, 26]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10575,
#   'entity_data': {'surface_char_pos': array([54, 64]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([10, 11]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10577,
#   'entity_data': {'surface_char_pos': array([ 0, 10]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([0, 1]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10577,
#   'entity_data': {'surface_char_pos': array([268, 281]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([41, 43]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 10579,
#   'entity_data': {'surface_char_pos': array([41, 51]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([8, 9]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10579,
#   'entity_data': {'surface_char_pos': array([365, 394]),
#    'surface_form': 'piper tuberculatum piperaceae',
#    'surface_word_pos': array([48, 51]),
#    'types': array([], dtype=object),
#    'uri': 'piper tuberculatum piperaceae'},
#   'uri': 'piper tuberculatum piperaceae'},
#  {'source_id': 10581,
#   'entity_data': {'surface_char_pos': array([82, 92]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([13, 14]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10582,
#   'entity_data': {'surface_char_pos': array([63, 73]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([11, 12]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10583,
#   'entity_data': {'surface_char_pos': array([ 92, 102]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([15, 16]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10583,
#   'entity_data': {'surface_char_pos': array([519, 529]),
#    'surface_form': 'fagaramide',
#    'surface_word_pos': array([68, 69]),
#    'types': array([], dtype=object),
#    'uri': 'fagaramide'},
#   'uri': 'fagaramide'},
#  {'source_id': 10608,
#   'entity_data': {'surface_char_pos': array([85, 95]),
#    'surface_form': 'fagaramide',
#    'surface_word_pos': array([15, 16]),
#    'types': array([], dtype=object),
#    'uri': 'fagaramide'},
#   'uri': 'fagaramide'},
#  {'source_id': 10609,
#   'entity_data': {'surface_char_pos': array([ 4, 14]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([1, 2]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10610,
#   'entity_data': {'surface_char_pos': array([189, 199]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([33, 34]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10612,
#   'entity_data': {'surface_char_pos': array([151, 161]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([21, 22]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10615,
#   'entity_data': {'surface_char_pos': array([305, 318]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([57, 59]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 10617,
#   'entity_data': {'surface_char_pos': array([ 0, 10]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([0, 1]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10621,
#   'entity_data': {'surface_char_pos': array([34, 44]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([6, 7]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10622,
#   'entity_data': {'surface_char_pos': array([ 6, 16]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([1, 2]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10630,
#   'entity_data': {'surface_char_pos': array([387, 397]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([78, 79]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10635,
#   'entity_data': {'surface_char_pos': array([104, 114]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([25, 26]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10636,
#   'entity_data': {'surface_char_pos': array([54, 64]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([10, 11]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10638,
#   'entity_data': {'surface_char_pos': array([ 0, 10]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([0, 1]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10638,
#   'entity_data': {'surface_char_pos': array([268, 281]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([41, 43]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 10640,
#   'entity_data': {'surface_char_pos': array([41, 51]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([8, 9]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10640,
#   'entity_data': {'surface_char_pos': array([365, 394]),
#    'surface_form': 'piper tuberculatum piperaceae',
#    'surface_word_pos': array([48, 51]),
#    'types': array([], dtype=object),
#    'uri': 'piper tuberculatum piperaceae'},
#   'uri': 'piper tuberculatum piperaceae'},
#  {'source_id': 10642,
#   'entity_data': {'surface_char_pos': array([82, 92]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([13, 14]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10643,
#   'entity_data': {'surface_char_pos': array([63, 73]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([11, 12]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10644,
#   'entity_data': {'surface_char_pos': array([ 92, 102]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([15, 16]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10644,
#   'entity_data': {'surface_char_pos': array([519, 529]),
#    'surface_form': 'fagaramide',
#    'surface_word_pos': array([68, 69]),
#    'types': array([], dtype=object),
#    'uri': 'fagaramide'},
#   'uri': 'fagaramide'},
#  {'source_id': 10669,
#   'entity_data': {'surface_char_pos': array([85, 95]),
#    'surface_form': 'fagaramide',
#    'surface_word_pos': array([15, 16]),
#    'types': array([], dtype=object),
#    'uri': 'fagaramide'},
#   'uri': 'fagaramide'},
#  {'source_id': 10670,
#   'entity_data': {'surface_char_pos': array([ 4, 14]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([1, 2]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10671,
#   'entity_data': {'surface_char_pos': array([189, 199]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([33, 34]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10673,
#   'entity_data': {'surface_char_pos': array([151, 161]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([21, 22]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10676,
#   'entity_data': {'surface_char_pos': array([305, 318]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([57, 59]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 10678,
#   'entity_data': {'surface_char_pos': array([ 0, 10]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([0, 1]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10682,
#   'entity_data': {'surface_char_pos': array([34, 44]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([6, 7]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10683,
#   'entity_data': {'surface_char_pos': array([ 6, 16]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([1, 2]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10691,
#   'entity_data': {'surface_char_pos': array([387, 397]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([78, 79]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10696,
#   'entity_data': {'surface_char_pos': array([104, 114]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([25, 26]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10697,
#   'entity_data': {'surface_char_pos': array([54, 64]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([10, 11]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10699,
#   'entity_data': {'surface_char_pos': array([ 0, 10]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([0, 1]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10699,
#   'entity_data': {'surface_char_pos': array([268, 281]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([41, 43]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 10701,
#   'entity_data': {'surface_char_pos': array([41, 51]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([8, 9]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10701,
#   'entity_data': {'surface_char_pos': array([365, 394]),
#    'surface_form': 'piper tuberculatum piperaceae',
#    'surface_word_pos': array([48, 51]),
#    'types': array([], dtype=object),
#    'uri': 'piper tuberculatum piperaceae'},
#   'uri': 'piper tuberculatum piperaceae'},
#  {'source_id': 10703,
#   'entity_data': {'surface_char_pos': array([82, 92]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([13, 14]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10704,
#   'entity_data': {'surface_char_pos': array([63, 73]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([11, 12]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10705,
#   'entity_data': {'surface_char_pos': array([ 92, 102]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([15, 16]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10705,
#   'entity_data': {'surface_char_pos': array([519, 529]),
#    'surface_form': 'fagaramide',
#    'surface_word_pos': array([68, 69]),
#    'types': array([], dtype=object),
#    'uri': 'fagaramide'},
#   'uri': 'fagaramide'},
#  {'source_id': 10730,
#   'entity_data': {'surface_char_pos': array([85, 95]),
#    'surface_form': 'fagaramide',
#    'surface_word_pos': array([15, 16]),
#    'types': array([], dtype=object),
#    'uri': 'fagaramide'},
#   'uri': 'fagaramide'},
#  {'source_id': 10731,
#   'entity_data': {'surface_char_pos': array([ 4, 14]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([1, 2]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10732,
#   'entity_data': {'surface_char_pos': array([189, 199]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([33, 34]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10734,
#   'entity_data': {'surface_char_pos': array([151, 161]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([21, 22]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10737,
#   'entity_data': {'surface_char_pos': array([305, 318]),
#    'surface_form': 'araraquara sp',
#    'surface_word_pos': array([57, 59]),
#    'types': array([], dtype=object),
#    'uri': 'araraquara sp'},
#   'uri': 'araraquara sp'},
#  {'source_id': 10739,
#   'entity_data': {'surface_char_pos': array([ 0, 10]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([0, 1]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10743,
#   'entity_data': {'surface_char_pos': array([34, 44]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([6, 7]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10744,
#   'entity_data': {'surface_char_pos': array([ 6, 16]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([1, 2]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10752,
#   'entity_data': {'surface_char_pos': array([387, 397]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([78, 79]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  {'source_id': 10757,
#   'entity_data': {'surface_char_pos': array([104, 114]),
#    'surface_form': 'antifungal',
#    'surface_word_pos': array([25, 26]),
#    'types': array([], dtype=object),
#    'uri': 'antifungal'},
#   'uri': 'antifungal'},
#  ...]

# %%
data_2
# Out:
# [{'label': 0,
#   'text_a': 'geranylation of benzoic acid derivatives by enzymatic extracts from piper crassinervium piperaceae silvia noelí lópez a adriana aparecida lopes a joão marcos batista jr a otávio flausino jr a vanderlan da silva bolzani a massuo jorge kato b maysa furlan a a nubbe núcleo de bioensaios biossíntese e ecoﬁsiologia de produtos naturais departamento de química orgânica instituto de química universidade estadual paulista unesp c p'},
#  {'label': 1,
#   'text_a': 'araraquara sp brazil b instituto de química universidade de são paulo usp av'},
#  {'label': 2,
#   'text_a': 'prof lineu prestes são paulo sp brazil a r t i c l e i n f o article history received july received in revised form january accepted january available online february keywords piper crassinervium piperaceae biotransformation geranylation a b s t r a c t the ability to carry out geranylations on aromatic substrates using enzymatic extracts from the leaves of piper crassinervium piperaceae was evaluated'},
#  {'label': 3,
#   'text_a': 'a literature analysis pointed out its importance as a source of prenylated bioactive molecules the screening performed on aromatic acceptors benzoic acids phenols and phenylpropanoids including geranyl diphosphate as prenyl donor showed the biotransfor mation of the dihydroxybenzoic acid by the crude extract and the p hydroxybenzoic acid by both the microsomal fraction and the crude extract after treating leaves with glucose'},
#  {'label': 4,
#   'text_a': 'the analysis of the products allowed the identiﬁcation of c and o geranylated derivatives and the protease subtilisin and pepsin inhibition performed on the o geranylated compounds showed weak inhibition electrophoretic proﬁles indicated the presence of bands spots among kda and pi which are compatible with pren yltransferases'},
#  {'label': 5,
#   'text_a': 'these ﬁndings show that p crassinervium could be considered as a source of extracts with geranyltransferase activity to perform biotransformations on aromatic substrates elsevier ltd all rights reserved introduction biotransformations are chemical reactions catalyzed by cells organs or enzymes they are different from biosynthesis where complex products are assembled from simple substrates by whole cells organs or organisms'},
#  {'label': 6,
#   'text_a': 'plant enzyme biocatalysts can be uti lized to introduce new structural motifs on existing drugs expect ing to improve their bioactivity pharmacokinetic proﬁle and also for the production of new drugs giri et al so far natural products bearing one or more prenyl groups have been isolated predominantly from higher plants'},
#  {'label': 7,
#   'text_a': 'these com pounds originated from several natural product classes often hold antimicrobial antioxidant anti inﬂammatory antiviral and anti cancer activities epifano et al since the prenylation of small aromatic molecules is a pivotal step in the biosynthesis of many natural products the access to prenylation reaction catalysts might represent an advantageous short cut to obtain prenylated aromatic compounds yazaki et al haagena et al'},
#  {'label': 8,
#   'text_a': 'aromatic geranyltransferases are a sub class of prenyltransfe rases that catalyzes c geranylations on several aromatic sub strates several examples of new aromatic prenyltransferases have been reported from bacteria as soluble monomeric biocata lysts with a relatively high promiscuity for aromatic substrates'},
#  {'label': 9,
#   'text_a': 'in spite of the lack of a full elucidation of substrate and regio speciﬁcity these enzymes were successfully employed to carry out either c or o prenylations of several compounds epifano et al in plants aromatic geranyltransferases are mem brane bound proteins showing a strict substrate speciﬁcity for the endogenous prenyl donor groups e g dmapp gpp etc'},
#  {'label': 10,
#   'text_a': 'although they may accept a variety of aromatic compounds as acceptors of the prenyl moieties yazaki et al kuzuyama et al there are few examples in which prenyltransferases have been isolated and characterized from plants mühlenweg et al therefore biotransformations using plant enzymatic extracts enriched in prenyltransferase activity could be used as an alternative to obtain either known or new bioactive compounds'},
#  {'label': 11,
#   'text_a': 'piperaceae family is a basal angiosperm family comprising more than species'},
#  {'label': 12,
#   'text_a': 'its species are chemically very rich and major classes of compounds described include phenylpropanoids orjala et al lignan neolignans parmar et al bene vides et al martins et al felippe et al pyrones singh aliphatic and aromatic amides alécio et al silva et al alkaloids dodson et al polyketides cheng et al benzoic acid derivatives bergamo et al morandim et al and chromenes lago et al morandim et al salazar et al'},
#  {'label': 13,
#   'text_a': 'belonging to this see front matter elsevier ltd all rights reserved doi j biortech corresponding author tel x fax e mail addresses maysaf iq unesp br maysaf reitoria unesp br m furlan these authors contributed equally to this work as second authors'},
#  {'label': 14,
#   'text_a': 'bioresource technology contents lists available at sciencedirect bioresource technology journal homepage www elsevier com locate biortech family piper is one of the most abundant genera with approxi mately species wanke et al piper crassinervium spe cies accumulates antifungal trypanocidal and antioxidant c geranylated metabolites derived from both benzoic acid and p hydroquinone danelutte et al yamaguchi et al lopes et al'},
#  {'label': 15,
#   'text_a': 'in spite of the knowledge on the chemical constituents and the biological potential of piperaceae species no comprehensive study has been made in order to survey such bioactive metabolites with in the members of the family here we present a compilation that points out to the impor tance of piper genus as a source of bioactive compounds and par ticularly of p crassinervium as an enzyme source to perform geranylations on aromatic substrates we report the biotransfor mation i e'},
#  {'label': 16,
#   'text_a': 'the geranylation of both the p hydroxybenzoic and dihydroxybenzoic acids carried out by the enzymatic extracts from the leaves of p crassinervium besides the full characterization of two products as geranyl ester derivatives in addition to the char acterization of one major product formed by biotransformation of the dihydroxybenzoic acid as a c geranylated derivative'},
#  {'label': 17,
#   'text_a': 'addi tionally the inhibitory activity on hiv like proteases was determined for the products as well as the electrophoretic charac terization of catalytically active protein fractions by using sds page and de methods literature survey and analysis piperaceae and activity were used as key words to perform a search in the available databases e g science direct and acs dat abases'},
#  {'label': 18,
#   'text_a': 'all the obtained information was uploaded in a table according to genus species type of compound and biological activ ity reported see the electronic annex in the online version of this article typical software excel microsoft corporation was used to analyse and plot the obtained information plant material fresh leaves of p crassinervium were collected from adults spec imens cultivated from seeds under greenhouse conditions at the institute of chemistry unesp araraquara sp brazil'},
#  {'label': 19,
#   'text_a': 'plant material was authenticated by dr guillermo paredes universidad pedro ruiz gallo peru and the voucher specimen kato was deposited at the herbarium of instituto de botânica são paulo sp brazil incubation into b d glucose of young leaves from p crassiner vium leaves freshly excised from an adult plant were placed sep arately in ml eppendorf tubes and each administrated ll from a solution of b d glucose in water at c for h berg amo et al'},
#  {'label': 20,
#   'text_a': 'synthesis and puriﬁcation of geranyl diphosphate gpp in a ml round bottom ﬂask mmol of geraniol was mixed with mmol of trichloroacetonitrile bis triethylammonium phos phate mmol in ml of acetonitrile was added drop wise to the mixture over a period of h at room temperature under con tinuous stirring cornforth and popják'},
#  {'label': 21,
#   'text_a': 'the mixture was fur ther stirred for h at room temperature and then the reaction was stopped by dilution with ml of ethyl ether followed by extraction with ml of nh oh m the basic solution was then re extracted with ml of ethyl ether and evapo rated under reduced pressure'},
#  {'label': 22,
#   'text_a': 'the gpp was puriﬁed by precipita tion in acetonitrile at c overnight compared with a commercial sample using tlc on cellulose isopropanol aque ous ammonia water and characterized by h c and p nmr h nmr mhz d o d h d j hz h t j hz h and h m h m ch s ch s ch s'},
#  {'label': 23,
#   'text_a': 'c nmr mhz d o d c c c c c c c c c and c p nmr h po mhz d o d p p'},
#  {'label': 24,
#   'text_a': 'synthesis puriﬁcation and characterization of the o geranyl derivatives of the dihydroxybenzoic acid to a stirred solution of the dihydroxibenzoic acid mmol in dry dmf ml anhydrous potassium carbonate mmol was added and the solution stirred for min at c under nitrogen atmosphere pisco et al geranyl bromide mmol was added drop wise and the resulting mixture was heated and stirred at the same temperature for h under nitrogen atmosphere'},
#  {'label': 25,
#   'text_a': 'the mixture was then poured into cold water ml added with of hoac and extracted with chcl ml and etoac ml the etoac layer was washed dried with na so and evaporated under reduced pressure and the residue was submitted to column chromatography silica gel mesh iso cratic elution with hex etoac yielding ﬁve fractions fraction was characterized as compound fraction as com pound and fraction as compound'},
#  {'label': 26,
#   'text_a': 'the puriﬁed products were characterized by h c nmr dept ghmbc ghmqc and esi ms fig table synthesis puriﬁcation and characterization of the o geranyl derivatives of the p hydroxybenzoic acid the p hydroxybenzoic acid mmol dissolved in ml of thf was added to a slurry of g of al o neutral in ether ml glü senkamp and büchi the solvent was evaporated and gera nyl bromide mmol in ether hexane was added'},
#  {'label': 27,
#   'text_a': 'after stirring during days al o was ﬁltered off and washed with hoac in etoac the combined organic layer was evaporated and the products were puriﬁed using column chromatography silica gel mesh gradient elution with hex hex etoac yielding fractions'},
#  {'label': 28,
#   'text_a': 'from fraction it was characterized the geranyl ester derivative whereas the geranyl ether derivative was puriﬁed from fraction by subsequent column chromatography silica gel mesh isocratic elution with hex etoac the puriﬁed products were characterized by h c nmr dept ghmbc ghmqc and esi ms table fig protein extraction leaves of p crassinervium were harvested from an adult speci men and maintained in liquid n'},
#  {'label': 29,
#   'text_a': 'the frozen leaves g were triturated in a mortar with addition of polyvinylpolypyrroli done pvpp mm dithiothreitol dtt and mm ethylenedi aminetetraacetic acid edta in ml of mm potassium phosphate kpi ph the homogenate was stirred slowly by min in ice bath ﬁltered on gauze and centrifuged at rpm for min to obtain the supernatant crude enzymatic extract which was then submitted to protein determination activity assay and electrophoretic analysis'},
#  {'label': 30,
#   'text_a': 'microsomal fraction the protocol was performed according to mühlenweg et al with minimal modiﬁcations the supernatant ml ob tained as described in section was subjected to ultracentrifuga s n lópez et al bioresource technology tion at rpm for h the resulting pellet was resuspended in ml of m tris hcl ph containing mm dtt m kcl and w v glycerol and stirred on ice for min'},
#  {'label': 31,
#   'text_a': 'the suspen sion was subjected to ultracentrifugation as described above the supernatant was discarded and the tube was carefully rinsed with m tris hcl ph the pellet was then resuspended in ml of m tris hcl ph containing mm dtt m kcl w v glycerol and mm cholamidopropyl dimethylammo nium hydroxy propanesulphonate chapso and stirred on ice for min'},
#  {'label': 32,
#   'text_a': 'the suspension was ultracentrifuged as described above and the desired proteins were recovered as supernatant which was passed through a sephadex g column cm long cm i d previously equilibrated with the m tris hcl ph containing mm chapso mm dtt and w v glycerol the eluate was submitted to protein determination activity assay and electrophoretic analysis'},
#  {'label': 33,
#   'text_a': 'protein determination the protein determination was performed by the bradford modiﬁed method using bovine serum albumin bsa as standard stoscheck detection of the geranyltransferase activity the reaction mixture ll containing mm kpi ph mm of precursors mm gpp mm mgcl or mncl and ll of the proteic extract was incubated under stirring for min at c the reaction was stopped with the addition of ll of m hcl and extracted with ll of etoac'},
#  {'label': 34,
#   'text_a': 'after vortex and centrifugation the organic layer was evaporated the residue dissolved in meoh ll and analysed by hplc uv using a phenomenex gemini column lm c å mm at a ﬂow rate of ml min an isocratic condition min con sisted of acetonitrile and aqueous hoac with detection at and nm injection volume ll'},
#  {'label': 35,
#   'text_a': 'for each reaction two negative controls which consisted of enzymatic extract buffer and precursor divalent cation gpp buffer were carried out simultaneously each experiment was performed in duplicate sodium dodecylsulphate polyacrylamide electrophoresis sds page the sds page was performed according to the supplier infor mation ge healthcare the polyacrylamide gels were stained with agno'},
#  {'label': 36,
#   'text_a': 'the relative molecular mass mr of denatured proteins was estimated using the labimage d software cali brated with low molecular weight standards phosphorylase b sericalbumin ovalbumin carbonic anhydrase and trypsin inhibi tor with and kda respectively two dimensional electrophoresis de the de with immobilized ph gradients ipg dalt was carried out according to the supplier information ge healthcare'},
#  {'label': 37,
#   'text_a': 'the ipg strips cm were rehydrated for h with sample pro teins previously treated with the clean up kit ge healthcare table h nmr data mhz j hz cdcl c nmr data mhz cdcl and ghmbc correlations observed for compounds o o o r r r r r h r r r h o r r r r h'},
#  {'label': 38,
#   'text_a': 'position h nmr c nmr ghmbc d d d coo d d d dd dd dd coo d d d coo tbr t t m m m m m m tbr t t s s s s s s s s s coo cooh n o'},
#  {'label': 39,
#   'text_a': 'n o oh n o n o oh n o n o note not observed from the correlations observed in ghmbc s n lópez et al bioresource technology in an immobiline drystrip reswelling tray first dimension iso electric focusing ief was carried out in an ettan ipgphor ii man ifold applying a manufacturer s standard protocol'},
#  {'label': 40,
#   'text_a': 'the second dimension was performed on a vertical cm poly acrylamide sds gel in a se ruby system ma gel and v each gel was stained with silver according to the silver staining protocol amersham biosciences inhibition of the protease activity reagents pepsin was from porcine gastric mucous'},
#  {'label': 41,
#   'text_a': 'recombinant type viii subtilisin carlsberg arg glu edans ser gln asn tyr pro ile val gln lys dabcyl arg ﬂuorogenic substrate edans dabcyl and dimethylsulphoxide dmso spectrophotometric grade were from sigma aldrich são paulo brazil protease activity assay the assays were performed in triplicate compounds were dis solved in dmso and diluted in m sodium phosphate ph for subtilisin and m sodium acetate ph for pepsin respec tively'},
#  {'label': 42,
#   'text_a': 'warfarin and dicoumarol were used as positive controls thaisrivongs et al pochet et al samples and stan dard inhibitors lg ml were pre incubated with subtilisin nm or pepsin nm for h and then transferred to a black opaque microplate to be tested the substrate edans dabcyl lm was prepared in the speciﬁc buffer for each protease in the control assay only protease and substrate were used'},
#  {'label': 43,
#   'text_a': 'proteases were prepared in the day of the experiment and the tests were per formed for each one separately readings were made using nm excitation and nm emission ﬁlters during min with min intervals at c hirata et al the ﬂuorescence intensity was used to calculate the of inhibition as follows i ¼ ½ðdfs dfpþ where dfs and dfp are the difference between the ﬁrst and last readings for the sample test and the control respectively'},
#  {'label': 44,
#   'text_a': 'fluorescence bioassay data were collected with a multidetec tion microplate reader synergy ht and analysed using the kc software bio tek instruments inc and microsoft windows xp results and discussion prenylation is a chemical or enzymatic addition of a hydropho bic side chain to an accepting molecule another terpenoid mole cule an aromatic compound a protein etc'},
#  {'label': 45,
#   'text_a': 'in particular the prenylation of aromatic secondary metabolites plays a critical role in the biosynthesis of a wide range of molecules exerting valuable pharmacological effects several examples can be found in phylo genetically different classes of living organisms from bacteria across mammals to plants epifano et al phytochemical investigations carried out on piper species have led to the isolation of many bioactive natural products'},
#  {'label': 46,
#   'text_a': 'the analy sis of the distribution of these bioactive compounds by genus type of compound and bioactivity in the piperaceae family was performed looking at particularly the importance of prenylated natural products within that universe the search was performed using piperaceae and activity as key words in the available web databases this search resulted in entries see the elec tronic annex in the online version of this article which were ana lysed and discussed here'},
#  {'label': 47,
#   'text_a': 'the analysis was performed considering the botanical classiﬁcation as provided in the publications regarding the distribution of bioactive compounds reported within genera a predominance of piper genus over peperomia genus was observed representing in spite of the large number of species belonging to peperomia genus about species ver sus from piper wanke et al it only contributes with of the total reports published'},
#  {'label': 48,
#   'text_a': 'such differences can be ac counted for the fact that piper species have been more exhaustively table h nmr data mhz j hz cdcl for compounds and c nmr data mhz cdcl and ghmbc correlations for compound o o o r r r r h r r h'},
#  {'label': 49,
#   'text_a': 'position compound compound h nmr c nmr ghmbc h nmr d coo d d d d d d coo d d coo d t tbr m m m m t tbr s s s s s s cooh n o'},
#  {'label': 50,
#   'text_a': 'oh n o note not observed oh oh o cooh oh o sarcorhachis ottonia pothomorphe p crassinervium fig distribution of piperaceae members considering the report of some biological activity for their isolated compounds'},
#  {'label': 51,
#   'text_a': 'the abundance of piper crassiner vium is highlighted and the structure of the geranylated bioactive compounds hydroxy e dimethyl oxo octadienyl benzoic acid and dihy droxy e dimethyl oxo octadienyl benzene is presented for details see the electronic annex s n lópez et al bioresource technology studied partially due to their wide occurrence and biomass avail ability fig electronic annex'},
#  {'label': 52,
#   'text_a': 'among piper genus species were subjected to phytochemical or bioactivity investigations being p cubeba the most intensively studied with near followed by p longum and p aduncum with p methysticum and p tuberculatum with p sanctum p ni grum and p crassinervium with fig only nine studies with peperomia species were found with p duclouxii p dindygul ensis and p galioides being the three mentioned most frequently'},
#  {'label': 53,
#   'text_a': 'considering the type of compounds they were grouped based on their structural characteristics as follows alk alkaloids and other substances bearing nitrogen lg lignans neolignans and re lated compounds pct polyketides tp terpenoids bppr preny lated benzopyrans hqpr prenylated hydroquinones bpr prenylated benzoic acid derivatives flv ﬂavonoids chalcones and related compounds b benzene derivatives bp benzopyr anes ag fatty acids fp phenylpropanoids e epoxides et steroids chx cyclohexanic derivatives kln kavalactones pyr ones and related compounds and npt naphthalene derivatives fig'},
#  {'label': 54,
#   'text_a': 'a their distribution shows the prevalence of nitrogenated substances alk lignoids lg and ﬂavonoids flv in piper spe cies nevertheless some differences could be observed in pepero mia where lg lignoids and bppr prenylated benzopyrans were the most abundant fig a'},
#  {'label': 55,
#   'text_a': 'regarding biological activities the grouping was performed considering the biological target in order to simplify as follows snc involving activities related to central nervous system such as sedative and relaxant tryp antiprotozoal activity against try panosoma plasmodium leishmania cyt cytotoxicity and related activities atb antimicrobial such as antibacterial and antifungal can anticancer activity related to cytotoxic but more speciﬁcally targeted insec insecticidal or repellent activity such as anti mosquito or ant aox antioxidant activity such as dpph enz inhibiroty activity against several enzymes aai anti inﬂamma tory activity acoag anticoagulant such as inhibition of platelet aggregation iger allelophatic activity photo photo protecting activity cic cicatrizing activity and avir antiviral activity'},
#  {'label': 56,
#   'text_a': 'the obtained distribution shows that piper genus is mostly related to antibacterial and antiprotozoal activities followed by anti inﬂam matory and enzymatic inhibitory activities while peperomia ap pears to be mostly related to cytotoxic and antiprotozoal activities only pothomorphe genus showed some relationship with antiviral activity fig b fig a distribution by type of bioactive compounds reported by genera in piperaceae family'},
#  {'label': 57,
#   'text_a': 'alk substances bearing nitrogen at the molecule lg lignans neolignans and related compounds pct polyketides tp terpenoids bppr prenylated benzopyrans hqpr prenylated hydroquinones bpr prenylated benzoic acid derivatives flv ﬂavonoids chalcones and related compounds b benzene derivatives bp benzopyrans ag fatty acids fp phenylpropanoids e epoxides et steroids chx cyclohexanic derivatives kln kavalactones pyrones and related compounds and npt naphthalene derivatives'},
#  {'label': 58,
#   'text_a': 'b distribution observed by biological activity groups for each genus reported snc related to central nervious system such as sedative and relaxant tryp antiprotozoal activity against trypanosoma plasmodium leishmania cyt cytotoxicity and related atb antimicrobial such as antibacterial and antifungal can anticancer activity related to cytotoxic but more speciﬁcally targeted insec insecticidal or repellent activity such as anti mosquito or ant aox antioxidant activity such as dpph enz inhibiroty activity against several enzymes aai anti inﬂammatory activity acoag anticoagulant such as inhibition of platelet aggregation iger allelophatic activity photo photo protecting activity cic cicatrizing activity and avir antiviral activity for details see the electronic annex'},
#  {'label': 59,
#   'text_a': 's n lópez et al bioresource technology about prenylated natural products i e all the compounds bear ing one or more prenyl geranyl farnesyl or geranylgeranyl moie ties as substituents in their basic structures open or cycled bp bpr bppr and hqpr they could be found in peperomia pothomor phe and in piper species fig'},
#  {'label': 60,
#   'text_a': 'in addition they are mostly related to antimicrobial atb insecticidal insec and antioxidant activity aox being the prenylated benzoic acid derivatives bpr from pi per species the group with the most biological activities reported fig the analysis for the occurrence of major secondary compounds pointed out that piper species could be considered as an important source of prenylated compounds and thus a source for further studies of prenyltransferase activity'},
#  {'label': 61,
#   'text_a': 'the two species p crassinervi um and p aduncum accounted for of the total number of spe cies in which bioactive substances have been reported for this genus and can be considered good candidates for further investiga tion on bioactive prenylated metabolites fig electronic annex'},
#  {'label': 62,
#   'text_a': 'considering the literature survey performed here as well as our previous experience on both bioactivity and biosynthetic studies of prenylated compounds from some piper species p crassinervium was selected for further studies lopes et al'},
#  {'label': 63,
#   'text_a': 'this species accumulates two c geranylated metabolites derived from benzoic acid hydroxy e dimethyl oxo octadienyl ben zoic acid and from benzenediol dihydroxy e dimethyl oxo octadienyl benzene which showed antifungal antioxidant and trypanocidal activities fig danelutte et al yamaguchi et al lopes et al'},
#  {'label': 64,
#   'text_a': 'a screening for the prenylation activity with the crude enzy matic extract from fresh leaves of p crassinervium plus geranyl pyrophosphate gpp as the prenyl donor a divalent cation mgcl or mncl and several aromatic substrates p hydroxybenzoic acid dihydroxybenzoic acid p hydroxybenzaldehyde phenol p hydroquinone caffeic acid o and p coumaric acids was initially performed'},
#  {'label': 65,
#   'text_a': 'neither the p hydroxybenzoic acid nor the p hydroqui none the two theoretically natural precursors of compounds and was biotransformed whilst the reaction with the dihydroxy benzoic acid led to the formation of products as observed in the chromatographic proﬁle suggesting a biotransformation reaction when compared with that of the negative control'},
#  {'label': 66,
#   'text_a': 'the reaction was consistently reproducible and the product was analysed by hplc uv ms showing an intense peak at tr min with kmax at nm besides some minor compounds between tr min fig the fact that the dihydroxybenzoic acid could be bio transformed is interesting because no prenylated natural products bearing a catechol moiety have been isolated from p crassinervium previously'},
#  {'label': 67,
#   'text_a': 'the characterization of the biotransformation products was performed by the analysis of their uv vis and ms or tandem ms ms esi negative mode spectra as well as by comparison with synthetic compounds prepared for this purpose the dihy droxybenzoic acid geranyl ester compound the o geranyl hydroxybenzoic acid compound and the o geranyl hydroxybenzoic acid compound table'},
#  {'label': 68,
#   'text_a': 'regarding the minor products detected chromatographic peaks detected at nm with tr between and min their mass ms spectra were investigated and compared to those of the synthetic compounds'},
#  {'label': 69,
#   'text_a': 'this analysis and the comparison of the chro matographic proﬁles uv amax and nm and ms spectra m h m c h and m c h co with those of the negative controls see section allowed the determination of the product eluted at tr min as the geranyl ester of the dihydroxybenzoic acid fig'},
#  {'label': 70,
#   'text_a': 'the compound eluted at tr min displayed a m h which under subsequent fragmentation by ms ms gave rise to the fragment ion m z indicating the loss of a co molecule fig considering that the addition of one geranyl moiety to this aromatic core produces a molecule with mw an additional oxidation at the geranylic chain was suggested on the basis of the mw observed compatible with additional unities to the mw'},
#  {'label': 71,
#   'text_a': 'this suggestion was based on the observation of the oxidation pattern of the isolated metabolites and which have a carbonyl carbon at their geranyl moieties fig the posi tion of the geranyl moiety could be proposed as a c at the aro matic ring instead of an o substitution at a phenol group due to the lack of the fragment at m z in the ms ms spectrum fig'},
#  {'label': 72,
#   'text_a': 'the position of the oxidation at the geranyl moiety was as sumed to be at c due to the observation of the fragment ions at m z and which could result from a mclafferty type rear rangement fig grossert et al since plant prenyltransferases are mostly membrane associated enzymes an additional protocol on the crude extract was per formed to obtain a microsomal fraction mühlenweg et al'},
#  {'label': 73,
#   'text_a': 'the process was monitored by electrophoresis sds page and de and the microsomal fraction was evaluated for its geranyl transferase activity having p hydroquinone p hydroxybenzoic and dihydroxybenzoic acids as aromatic acceptors no prod ucts were detected when p hydroquinone and dihydroxyben zoic acid were used as substrates'},
#  {'label': 74,
#   'text_a': 'nevertheless the analysis indicated that the p hydroxybenzoic acid was biotransformed yielding a new product as a weak chromatographic peak tr min absent in the negative controls the chromatographic proﬁle of the obtained product was compared with those of the endogenous and synthetic and table compounds sug gesting that the product of this biotransformation could be an o geranylated derivative fig'},
#  {'label': 75,
#   'text_a': 'previous studies carried out by our research group with leaves of p crassinervium have demonstrated that compounds and were biosynthesized de novo after incubation for three days with glucose unpublished results consequently a protocol of feeding glucose by pre incubation of fresh leaves from p crassinervium with a aqueous solution was applied to enhance the expres sion of the geranyltransferase activity'},
#  {'label': 76,
#   'text_a': 'subsequent to the enzymatic reaction the synthesis of the ex pected product was enhanced being possible to identify it as the geranylic ester of the p hydroxybenzoic acid both in the crude extract and in the microsomal fraction fig this result is fig distribution of prenylated bioactive metabolites by genera within pipera ceae family'},
#  {'label': 77,
#   'text_a': 'bppr prenylated benzopyrans hqpr prenylated hydroquinones bpr prenylated benzoic acid derivatives bp benzopyrans tryp antiprotozoal activity against trypanosoma plasmodium leishmania cyt cytotoxicity and related atb antimicrobial such as antibacterial and antifungal can anticancer activity related to cytotoxic but more speciﬁcally targeted insec insecticidal or repellent activity such as anti mosquito or ant aox antioxidant activity such as dpph enz inhibiroty activity against several enzymes aai anti inﬂammatory activity acoag anticoagulant such as inhibition of platelet aggregation iger allelophatic activity photo photo protecting activity cic cicatrizing activity and avir antiviral activity for details see the electronic annex'},
#  {'label': 78,
#   'text_a': 's n lópez et al bioresource technology complementary to a previous report of the geranylation of the p hydroxybenzoic acid to its ether derivative with a recombinant geranyltransferase from bacterial origin haagena et al'},
#  {'label': 79,
#   'text_a': 'nevertheless from the analysis of the spectral data of the product oh o oh ho o co m h m z a a h h h oh b b m z co m z oh ho o h h h b o o oh b a o o o oh a oh o oh ho scan es e m z silvia a lcms esi oh o o oh time mrm of channel es m z scan es'},
#  {'label': 80,
#   'text_a': 'x g s m s n a c s s m a i v l i s a n a i r d a e m z daughters of es e ms ms ms fig'},
#  {'label': 81,
#   'text_a': 'typical chromatogram obtained for the biotransformation of the dihydroxybenzoic acid using gpp and the crude enzymatic extract from the leaves of p crassinervium which shows the product identiﬁed as compound at tr min and the proposed fragmentation pattern of the product eluted at tr min based on the analysis of its ms and tandem ms ms divalent cation mgcl final concentrations mm reaction conditions min c'},
#  {'label': 82,
#   'text_a': 'chromatographic conditions acn hoac ml min inj vol ll min detection uv k nm esi negative mode v s n lópez et al bioresource technology obtained and characterized by haagena et al we propose that it is the ester derivative instead of the ether as reported'},
#  {'label': 83,
#   'text_a': 'the expected chemical shift value for the ch at d observed in the h nmr should be similar for the two derivatives and and therefore this data should not be enough to distinguish which derivative was formed thus further nmr experiments including analysis of the c nmr values and the ghmbc correlations were carried out the observed differences in the substrate speciﬁcity suggest the presence of at least two geranyltransferases in p crassinervi um'},
#  {'label': 84,
#   'text_a': 'one of them was soluble and showed afﬁnity to the dihy droxybenzoic acid while the second was concentrated in the microsomal fraction recognizing the p hydroxybenzoic acid as substrate and was inducible by glucose the sds page and de analysis indicated the concentration of spots between pi and kda in the microsomal fraction which is in agreement with previous reports for geranyltransferases from plants fig'},
#  {'label': 85,
#   'text_a': 'the two enzymatically formed products were characterized as o geranylated derivatives and were previously reported as syn thetic compounds kubo et al the production of esters in stead of ethers or c prenylated derivatives as naturally occurs in plants suggests that different conditions and environments could affect the prenylation outcome in crude and partly puriﬁed enzy matic extracts'},
#  {'label': 86,
#   'text_a': 'besides a c geranylated derivative of the dihy droxybenzoic acid bearing a carbonyl group at c could be proposed by the analysis of its ms ms fragmentation data our a b c d scan es e oh o o m z coo h oh co oh o h fig'},
#  {'label': 87,
#   'text_a': 'chromatographic analysis for the enzymatic reaction of the crude enzymatic extract from the leaves of p crassinervium before a and after b the treatment with glucose with p hydroxybenzoic acid and gpp c synthetic standard of the p hydroxybenzoic acid geranyl ester d negative control divalent cation mgcl final concentrations mm reaction conditions min c chromatographic conditions acn hoac ml min inj vol ll min detection uv k nm s n'},
#  {'label': 88,
#   'text_a': 'lópez et al bioresource technology observations are in agreement with previous reports based on bac terial recombinant aromatic prenyltransferases haagena et al in spite of the large number of data on phytochemistry and bio activity on piper species no studies have been addressed to deter mine their antiviral potential and the only exception involved the monotypic pothomorphe umbellata fig'},
#  {'label': 89,
#   'text_a': 'the inhibition of viral proteases has indeed been demonstrated to be a good target to search new drugs for the treatment of several illnesses including aids in this context the investigation on some common proteases such as subtilisin and pepsin is considered as a useful screening for the discovery of potential inhibitors of retroviral proteases hirata et al compounds and were tested as inhibitors of sub tilisin and pepsin using the ﬂuorescence resonance energy transfer fret methodology'},
#  {'label': 90,
#   'text_a': 'both compounds showed weak activity being the ester slightly more active than showing of inhibition at lg ml on pepsin and on subtilisin table warfarin and dicoumarol were tested as positive controls'},
#  {'label': 91,
#   'text_a': 'the hiv like protease inhibitory potential reported for and is the ﬁrst approach to the determination of antiviral activity of this kind of compounds and complements the range of biological activities previously reported such as antifungal and antibacterial kubo et al nihei et al conclusions prenylation of aromatic compounds represents an important feature when the formation of bioactive compounds in plants is concerned'},
#  {'label': 92,
#   'text_a': 'there are several examples in which different simple prenyl geranyl farnesyl geranylgeranyl or polyterpenic unities are added to aromatic substrates rendering them with important biological properties the literature survey indicated that among piperaceae family p crassinervium species appeared as an impor tant source of geranyltransferase activity looking at biotransforma tions reactions'},
#  {'label': 93,
#   'text_a': 'between the two substrates evaluated the p hydroxybenzoic acid was o geranylated whilst the dihydroxy benzoic acid was both c and o geranylated the o geranylated products presented a weak protease inhibitory activity the elec trophoretic analysis performed on the microsomal fraction showed a typical prenyltransferase electrophoretic proﬁle mr kda pi'},
#  {'label': 94,
#   'text_a': 'this work contributes to the comprehensive study of biotrans formation reactions with geranyl moieties using plant enzymatic extracts as an alternative strategy to the biocatalysis with puriﬁed enzymes acknowledgements the authors are grateful to prof wagner vilegas and dr alberto c alécio for the helpful discussions and suggestions regarding ms spectrometry'},
#  {'label': 95,
#   'text_a': 'this work was supported with grants provided by the state of são paulo research foundation fapesp and and was also supported by fapesp within the biota fapesp biodiversity virtual institute program www bio tasp org br snl aal jmbj and ofj wish to thank fapesp for the provision of scholarships m f m j k and v s b are also grateful to the national council for scientiﬁc and technological develop ment cnpq for research fellowships'},
#  {'label': 96,
#   'text_a': 'rf mr c e mr kda sds page de pi mr c e µ fr µ fr fig sds page and de of the crude extract ce and the microsomal fraction lfr from the leaves of p crassinervium de conditions for ce was used a cm ipg strip pi linear for lfr was used a cm ipg strip pi'},
#  {'label': 97,
#   'text_a': 'sds page and the second dimension of de were executed with of polyacrylamide gel monitored with lmw standards kda staining of gels was performed with agno silver staining protocol amersham biosciences digitalisation and image analysis were performed using labimage d and image master software table inhibitory activity for compounds and tested at lg ml on pepsin and subtilisin warfarin and dicoumarol were included as positive controls lg ml'},
#  {'label': 98,
#   'text_a': 'compound lg ml inhibition pepsin subtilisin lm lm warfarin lv dicoumarol lv s n lópez et al bioresource technology appendix a supplementary data supplementary data associated with this article can be found in the online version at doi j biortech references alécio a c bolzani v s young m c m kato m j furlan m antifungal amides from piper hispidum'},
#  {'label': 99,
#   'text_a': 'journal of natural products benevides p j c sartorelli p kato m j phenylpropanoids and neolignans from piper regnellii phytochemistry bergamo d c b kato m j bolzani v s furlan m biosynthetic origin of the isoprene units of nerolidylcathecol in pothomorphe umbellata journal of the brazilian chemical society cheng m lee s chang y wu s tsai i jayaprakasam b chen i'},
#  {'label': 100,
#   'text_a': 'chemical and cytotoxic constituents from peperomia sui phytochemistry cornforth r h popják g methods in enzimology steroids and terpenoids academic press san diego pp danelutte a p lago j h g young m c m kato m j antifungal ﬂavanones and prenylated hydroquinones from piper crassinervium kunth phytochemistry dodson c d dyer l a searcy j wright z letourneau d k'},
#  {'label': 101,
#   'text_a': 'cenocladamide a dihydropyridone alkaloid from piper cenocladum phytochemistry epifano f genovese s menghini l curini m chemistry and pharmacology of oxyprenylated secondary plant metabolites bioorganic and medicinal chemistry felippe l g baldoqui d c kato m j bolzani v s guimarães e f cicarelli r m b furlan m trypanocidal tetrahydrofuran lignans from peperomia blanda phytochemistry'},
#  {'label': 102,
#   'text_a': 'giri a dhingra v giri c c singh a ward o p narasu m l biotransformations using plant cells organ cultures and enzyme systems current trends and future prospects biotechnology advances glüsenkamp k h büchi g c prenylation of phenols promoted by aluminum oxide surfaces journal of organic chemistry grossert j s cook m c white r l'},
#  {'label': 103,
#   'text_a': 'the inﬂuence of structural features on facile mclafferty type even electron rearrangements in tandem mass spectra of carboxylate anions rapid communications in mass spectrometry haagena y unsöld i westrich l gust b richard s b noel j p heide l a soluble magnesium independent prenyltransferase catalyzes reverse and regular c prenylations and o prenylations of aromatic substrates febs letters'},
#  {'label': 104,
#   'text_a': 'hirata j chung l p ariese f irth h gooijer c coupling of size exclusion chromatography to a continuous assay for subtilisin using a ﬂuorescence resonance energy transfer peptide substrate testing of two standard inhibitors journal of chromatography a kubo i fujita k nihei k i molecular design of multifunctional antibacterial agents against methicillin resistant staphylococcus aureus mrsa bioorganic and medicinal chemistry'},
#  {'label': 105,
#   'text_a': 'kuzuyama t noel j p richard s b structural basis for the promiscuous biosynthetic prenylation of aromatic natural products nature lago j g l ramos c s casanova d c c morandim a a bergamo d c b cavalheiro a j bolzani v s furlan m guimarães e f young m m c kato m j benzoic acid derivates from piper species and their fungitoxic activity against cladosporium cladosporioides and c sphaerospermum journal of natural products'},
#  {'label': 106,
#   'text_a': 'lopes a a lópez s n regasini l o batista jr j m ambrósio d l kato m j bolzani v s cicarelli r m b furlan m in vitro activity of compounds isolated from piper crassinervium against trypanosoma cruzi natural products research martins r c lago j h g kato m j trypanocidal tetrahydrofuran lignans from piper solmsianum phytochemistry morandim a a bergamo d c b kato m j cavalheiro a j bolzani v s furlan m'},
#  {'label': 107,
#   'text_a': 'circadian rhythm of anti fungal prenylated chromene in leaves of piper aduncum phytochemical analysis mühlenweg a melzer m li s heide l hydroxybenzoate geranyltranferase from lithospermum erythrorhizon puriﬁcation of a plant membrane bound prenyltransferase planta nihei k nihei a kubo i molecular design of multifunctional food additives antioxidative antifungal agents journal of the agriculture and food chemistry'},
#  {'label': 108,
#   'text_a': 'orjala j erdelmeier c a j wright a d rali t sticher o two chromenes and a prenylated benzoic acid derivative from piper aduncum phytochemistry parmar v s jain s c bisht k s jain r taneja p jha a tyagi o d prasad a k wengel j olsen c e boll p m phytochemistry of the genus piper phytochemistry'},
#  {'label': 109,
#   'text_a': 'pisco l kordian m peseke k feist h michalik d estrada e carvalho j hamilton g rando d quincoces j synthesis of compounds with antiproliferative activity as analogues of prenylated natural products existing in brazilian propolis european journal of medicinal chemistry pochet l doucet c dive g wouters j masereel b reboud ravaux m pirotte b'},
#  {'label': 110,
#   'text_a': 'coumarinic derivatives as mechanism based inhibitors of a chymotrypsin and human leukocyte elastase bioorganic and medicinal chemistry salazar k j m paredes g e d lluncor l r young m c m kato m j chromenes of polyketide origin in peperomia villipetiola phytochemistry silva r v navickiene h m d kato m j bolzani v s meda c i young m c m furlan m antifungal amides from piper arboreum and piper tuberculatum'},
#  {'label': 111,
#   'text_a': 'phytochemistry singh y n kava an overview journal of ethnopharmacology stoscheck c m methods in enzymology guide to protein puriﬁcation academic press san diego thaisrivongs s tomich p k watenpaugh k d chong k t howe w j yang c p strohbach j w turner s r mcgrath j p structure based design of hiv protease inhibitors hydroxycoumarins and hydroxy pyrones as non peptidic inhibitors'},
#  {'label': 112,
#   'text_a': 'journal of medicinal chemistry wanke s jaramillo m a borsch t samain m s quandt d neinhuis c evolution of piperales matk gene and trnk intron sequence data reveal lineage speciﬁc resolution contrast molecular phylogenetics and evolution yamaguchi l f lago j h g tanizaki t m di mascio p kato m j antioxidant activity of prenylated hydroquinone and benzoic acid derivatives from piper crassinervium kunth phytochemistry'},
#  {'label': 113,
#   'text_a': 'yazaki k matsuoka h shimomura k bechtold a sato f a novel dark induced protein ledi and its involvement in root speciﬁc secondary metabolism in lithospermum erythrorhizon plant physiology s n lópez et al bioresource technology'},
#  {'label': 114,
#   'text_a': 'geranylation of benzoic acid derivatives by enzymatic extracts from piper crassinervium piperaceae silvia noelí lópez a adriana aparecida lopes a joão marcos batista jr a otávio flausino jr a vanderlan da silva bolzani a massuo jorge kato b maysa furlan a a nubbe núcleo de bioensaios biossíntese e ecoﬁsiologia de produtos naturais departamento de química orgânica instituto de química universidade estadual paulista unesp c p'},
#  {'label': 115,
#   'text_a': 'araraquara sp brazil b instituto de química universidade de são paulo usp av'},
#  {'label': 116,
#   'text_a': 'prof lineu prestes são paulo sp brazil a r t i c l e i n f o article history received july received in revised form january accepted january available online february keywords piper crassinervium piperaceae biotransformation geranylation a b s t r a c t the ability to carry out geranylations on aromatic substrates using enzymatic extracts from the leaves of piper crassinervium piperaceae was evaluated'},
#  {'label': 117,
#   'text_a': 'a literature analysis pointed out its importance as a source of prenylated bioactive molecules the screening performed on aromatic acceptors benzoic acids phenols and phenylpropanoids including geranyl diphosphate as prenyl donor showed the biotransfor mation of the dihydroxybenzoic acid by the crude extract and the p hydroxybenzoic acid by both the microsomal fraction and the crude extract after treating leaves with glucose'},
#  {'label': 118,
#   'text_a': 'the analysis of the products allowed the identiﬁcation of c and o geranylated derivatives and the protease subtilisin and pepsin inhibition performed on the o geranylated compounds showed weak inhibition electrophoretic proﬁles indicated the presence of bands spots among kda and pi which are compatible with pren yltransferases'},
#  {'label': 119,
#   'text_a': 'these ﬁndings show that p crassinervium could be considered as a source of extracts with geranyltransferase activity to perform biotransformations on aromatic substrates elsevier ltd all rights reserved introduction biotransformations are chemical reactions catalyzed by cells organs or enzymes they are different from biosynthesis where complex products are assembled from simple substrates by whole cells organs or organisms'},
#  {'label': 120,
#   'text_a': 'plant enzyme biocatalysts can be uti lized to introduce new structural motifs on existing drugs expect ing to improve their bioactivity pharmacokinetic proﬁle and also for the production of new drugs giri et al so far natural products bearing one or more prenyl groups have been isolated predominantly from higher plants'},
#  {'label': 121,
# ...
#   'text_a': 'such differences can be ac counted for the fact that piper species have been more exhaustively table h nmr data mhz j hz cdcl for compounds and c nmr data mhz cdcl and ghmbc correlations for compound o o o r r r r h r r h'},
#  {'label': 961,
#   'text_a': 'position compound compound h nmr c nmr ghmbc h nmr d coo d d d d d d coo d d coo d t tbr m m m m t tbr s s s s s s cooh n o'},
#  {'label': 962,
#   'text_a': 'oh n o note not observed oh oh o cooh oh o sarcorhachis ottonia pothomorphe p crassinervium fig distribution of piperaceae members considering the report of some biological activity for their isolated compounds'},
#  {'label': 963,
#   'text_a': 'the abundance of piper crassiner vium is highlighted and the structure of the geranylated bioactive compounds hydroxy e dimethyl oxo octadienyl benzoic acid and dihy droxy e dimethyl oxo octadienyl benzene is presented for details see the electronic annex s n lópez et al bioresource technology studied partially due to their wide occurrence and biomass avail ability fig electronic annex'},
#  {'label': 964,
#   'text_a': 'among piper genus species were subjected to phytochemical or bioactivity investigations being p cubeba the most intensively studied with near followed by p longum and p aduncum with p methysticum and p tuberculatum with p sanctum p ni grum and p crassinervium with fig only nine studies with peperomia species were found with p duclouxii p dindygul ensis and p galioides being the three mentioned most frequently'},
#  {'label': 965,
#   'text_a': 'considering the type of compounds they were grouped based on their structural characteristics as follows alk alkaloids and other substances bearing nitrogen lg lignans neolignans and re lated compounds pct polyketides tp terpenoids bppr preny lated benzopyrans hqpr prenylated hydroquinones bpr prenylated benzoic acid derivatives flv ﬂavonoids chalcones and related compounds b benzene derivatives bp benzopyr anes ag fatty acids fp phenylpropanoids e epoxides et steroids chx cyclohexanic derivatives kln kavalactones pyr ones and related compounds and npt naphthalene derivatives fig'},
#  {'label': 966,
#   'text_a': 'a their distribution shows the prevalence of nitrogenated substances alk lignoids lg and ﬂavonoids flv in piper spe cies nevertheless some differences could be observed in pepero mia where lg lignoids and bppr prenylated benzopyrans were the most abundant fig a'},
#  {'label': 967,
#   'text_a': 'regarding biological activities the grouping was performed considering the biological target in order to simplify as follows snc involving activities related to central nervous system such as sedative and relaxant tryp antiprotozoal activity against try panosoma plasmodium leishmania cyt cytotoxicity and related activities atb antimicrobial such as antibacterial and antifungal can anticancer activity related to cytotoxic but more speciﬁcally targeted insec insecticidal or repellent activity such as anti mosquito or ant aox antioxidant activity such as dpph enz inhibiroty activity against several enzymes aai anti inﬂamma tory activity acoag anticoagulant such as inhibition of platelet aggregation iger allelophatic activity photo photo protecting activity cic cicatrizing activity and avir antiviral activity'},
#  {'label': 968,
#   'text_a': 'the obtained distribution shows that piper genus is mostly related to antibacterial and antiprotozoal activities followed by anti inﬂam matory and enzymatic inhibitory activities while peperomia ap pears to be mostly related to cytotoxic and antiprotozoal activities only pothomorphe genus showed some relationship with antiviral activity fig b fig a distribution by type of bioactive compounds reported by genera in piperaceae family'},
#  {'label': 969,
#   'text_a': 'alk substances bearing nitrogen at the molecule lg lignans neolignans and related compounds pct polyketides tp terpenoids bppr prenylated benzopyrans hqpr prenylated hydroquinones bpr prenylated benzoic acid derivatives flv ﬂavonoids chalcones and related compounds b benzene derivatives bp benzopyrans ag fatty acids fp phenylpropanoids e epoxides et steroids chx cyclohexanic derivatives kln kavalactones pyrones and related compounds and npt naphthalene derivatives'},
#  {'label': 970,
#   'text_a': 'b distribution observed by biological activity groups for each genus reported snc related to central nervious system such as sedative and relaxant tryp antiprotozoal activity against trypanosoma plasmodium leishmania cyt cytotoxicity and related atb antimicrobial such as antibacterial and antifungal can anticancer activity related to cytotoxic but more speciﬁcally targeted insec insecticidal or repellent activity such as anti mosquito or ant aox antioxidant activity such as dpph enz inhibiroty activity against several enzymes aai anti inﬂammatory activity acoag anticoagulant such as inhibition of platelet aggregation iger allelophatic activity photo photo protecting activity cic cicatrizing activity and avir antiviral activity for details see the electronic annex'},
#  {'label': 971,
#   'text_a': 's n lópez et al bioresource technology about prenylated natural products i e all the compounds bear ing one or more prenyl geranyl farnesyl or geranylgeranyl moie ties as substituents in their basic structures open or cycled bp bpr bppr and hqpr they could be found in peperomia pothomor phe and in piper species fig'},
#  {'label': 972,
#   'text_a': 'in addition they are mostly related to antimicrobial atb insecticidal insec and antioxidant activity aox being the prenylated benzoic acid derivatives bpr from pi per species the group with the most biological activities reported fig the analysis for the occurrence of major secondary compounds pointed out that piper species could be considered as an important source of prenylated compounds and thus a source for further studies of prenyltransferase activity'},
#  {'label': 973,
#   'text_a': 'the two species p crassinervi um and p aduncum accounted for of the total number of spe cies in which bioactive substances have been reported for this genus and can be considered good candidates for further investiga tion on bioactive prenylated metabolites fig electronic annex'},
#  {'label': 974,
#   'text_a': 'considering the literature survey performed here as well as our previous experience on both bioactivity and biosynthetic studies of prenylated compounds from some piper species p crassinervium was selected for further studies lopes et al'},
#  {'label': 975,
#   'text_a': 'this species accumulates two c geranylated metabolites derived from benzoic acid hydroxy e dimethyl oxo octadienyl ben zoic acid and from benzenediol dihydroxy e dimethyl oxo octadienyl benzene which showed antifungal antioxidant and trypanocidal activities fig danelutte et al yamaguchi et al lopes et al'},
#  {'label': 976,
#   'text_a': 'a screening for the prenylation activity with the crude enzy matic extract from fresh leaves of p crassinervium plus geranyl pyrophosphate gpp as the prenyl donor a divalent cation mgcl or mncl and several aromatic substrates p hydroxybenzoic acid dihydroxybenzoic acid p hydroxybenzaldehyde phenol p hydroquinone caffeic acid o and p coumaric acids was initially performed'},
#  {'label': 977,
#   'text_a': 'neither the p hydroxybenzoic acid nor the p hydroqui none the two theoretically natural precursors of compounds and was biotransformed whilst the reaction with the dihydroxy benzoic acid led to the formation of products as observed in the chromatographic proﬁle suggesting a biotransformation reaction when compared with that of the negative control'},
#  {'label': 978,
#   'text_a': 'the reaction was consistently reproducible and the product was analysed by hplc uv ms showing an intense peak at tr min with kmax at nm besides some minor compounds between tr min fig the fact that the dihydroxybenzoic acid could be bio transformed is interesting because no prenylated natural products bearing a catechol moiety have been isolated from p crassinervium previously'},
#  {'label': 979,
#   'text_a': 'the characterization of the biotransformation products was performed by the analysis of their uv vis and ms or tandem ms ms esi negative mode spectra as well as by comparison with synthetic compounds prepared for this purpose the dihy droxybenzoic acid geranyl ester compound the o geranyl hydroxybenzoic acid compound and the o geranyl hydroxybenzoic acid compound table'},
#  {'label': 980,
#   'text_a': 'regarding the minor products detected chromatographic peaks detected at nm with tr between and min their mass ms spectra were investigated and compared to those of the synthetic compounds'},
#  {'label': 981,
#   'text_a': 'this analysis and the comparison of the chro matographic proﬁles uv amax and nm and ms spectra m h m c h and m c h co with those of the negative controls see section allowed the determination of the product eluted at tr min as the geranyl ester of the dihydroxybenzoic acid fig'},
#  {'label': 982,
#   'text_a': 'the compound eluted at tr min displayed a m h which under subsequent fragmentation by ms ms gave rise to the fragment ion m z indicating the loss of a co molecule fig considering that the addition of one geranyl moiety to this aromatic core produces a molecule with mw an additional oxidation at the geranylic chain was suggested on the basis of the mw observed compatible with additional unities to the mw'},
#  {'label': 983,
#   'text_a': 'this suggestion was based on the observation of the oxidation pattern of the isolated metabolites and which have a carbonyl carbon at their geranyl moieties fig the posi tion of the geranyl moiety could be proposed as a c at the aro matic ring instead of an o substitution at a phenol group due to the lack of the fragment at m z in the ms ms spectrum fig'},
#  {'label': 984,
#   'text_a': 'the position of the oxidation at the geranyl moiety was as sumed to be at c due to the observation of the fragment ions at m z and which could result from a mclafferty type rear rangement fig grossert et al since plant prenyltransferases are mostly membrane associated enzymes an additional protocol on the crude extract was per formed to obtain a microsomal fraction mühlenweg et al'},
#  {'label': 985,
#   'text_a': 'the process was monitored by electrophoresis sds page and de and the microsomal fraction was evaluated for its geranyl transferase activity having p hydroquinone p hydroxybenzoic and dihydroxybenzoic acids as aromatic acceptors no prod ucts were detected when p hydroquinone and dihydroxyben zoic acid were used as substrates'},
#  {'label': 986,
#   'text_a': 'nevertheless the analysis indicated that the p hydroxybenzoic acid was biotransformed yielding a new product as a weak chromatographic peak tr min absent in the negative controls the chromatographic proﬁle of the obtained product was compared with those of the endogenous and synthetic and table compounds sug gesting that the product of this biotransformation could be an o geranylated derivative fig'},
#  {'label': 987,
#   'text_a': 'previous studies carried out by our research group with leaves of p crassinervium have demonstrated that compounds and were biosynthesized de novo after incubation for three days with glucose unpublished results consequently a protocol of feeding glucose by pre incubation of fresh leaves from p crassinervium with a aqueous solution was applied to enhance the expres sion of the geranyltransferase activity'},
#  {'label': 988,
#   'text_a': 'subsequent to the enzymatic reaction the synthesis of the ex pected product was enhanced being possible to identify it as the geranylic ester of the p hydroxybenzoic acid both in the crude extract and in the microsomal fraction fig this result is fig distribution of prenylated bioactive metabolites by genera within pipera ceae family'},
#  {'label': 989,
#   'text_a': 'bppr prenylated benzopyrans hqpr prenylated hydroquinones bpr prenylated benzoic acid derivatives bp benzopyrans tryp antiprotozoal activity against trypanosoma plasmodium leishmania cyt cytotoxicity and related atb antimicrobial such as antibacterial and antifungal can anticancer activity related to cytotoxic but more speciﬁcally targeted insec insecticidal or repellent activity such as anti mosquito or ant aox antioxidant activity such as dpph enz inhibiroty activity against several enzymes aai anti inﬂammatory activity acoag anticoagulant such as inhibition of platelet aggregation iger allelophatic activity photo photo protecting activity cic cicatrizing activity and avir antiviral activity for details see the electronic annex'},
#  {'label': 990,
#   'text_a': 's n lópez et al bioresource technology complementary to a previous report of the geranylation of the p hydroxybenzoic acid to its ether derivative with a recombinant geranyltransferase from bacterial origin haagena et al'},
#  {'label': 991,
#   'text_a': 'nevertheless from the analysis of the spectral data of the product oh o oh ho o co m h m z a a h h h oh b b m z co m z oh ho o h h h b o o oh b a o o o oh a oh o oh ho scan es e m z silvia a lcms esi oh o o oh time mrm of channel es m z scan es'},
#  {'label': 992,
#   'text_a': 'x g s m s n a c s s m a i v l i s a n a i r d a e m z daughters of es e ms ms ms fig'},
#  {'label': 993,
#   'text_a': 'typical chromatogram obtained for the biotransformation of the dihydroxybenzoic acid using gpp and the crude enzymatic extract from the leaves of p crassinervium which shows the product identiﬁed as compound at tr min and the proposed fragmentation pattern of the product eluted at tr min based on the analysis of its ms and tandem ms ms divalent cation mgcl final concentrations mm reaction conditions min c'},
#  {'label': 994,
#   'text_a': 'chromatographic conditions acn hoac ml min inj vol ll min detection uv k nm esi negative mode v s n lópez et al bioresource technology obtained and characterized by haagena et al we propose that it is the ester derivative instead of the ether as reported'},
#  {'label': 995,
#   'text_a': 'the expected chemical shift value for the ch at d observed in the h nmr should be similar for the two derivatives and and therefore this data should not be enough to distinguish which derivative was formed thus further nmr experiments including analysis of the c nmr values and the ghmbc correlations were carried out the observed differences in the substrate speciﬁcity suggest the presence of at least two geranyltransferases in p crassinervi um'},
#  {'label': 996,
#   'text_a': 'one of them was soluble and showed afﬁnity to the dihy droxybenzoic acid while the second was concentrated in the microsomal fraction recognizing the p hydroxybenzoic acid as substrate and was inducible by glucose the sds page and de analysis indicated the concentration of spots between pi and kda in the microsomal fraction which is in agreement with previous reports for geranyltransferases from plants fig'},
#  {'label': 997,
#   'text_a': 'the two enzymatically formed products were characterized as o geranylated derivatives and were previously reported as syn thetic compounds kubo et al the production of esters in stead of ethers or c prenylated derivatives as naturally occurs in plants suggests that different conditions and environments could affect the prenylation outcome in crude and partly puriﬁed enzy matic extracts'},
#  {'label': 998,
#   'text_a': 'besides a c geranylated derivative of the dihy droxybenzoic acid bearing a carbonyl group at c could be proposed by the analysis of its ms ms fragmentation data our a b c d scan es e oh o o m z coo h oh co oh o h fig'},
#  {'label': 999,
#   'text_a': 'chromatographic analysis for the enzymatic reaction of the crude enzymatic extract from the leaves of p crassinervium before a and after b the treatment with glucose with p hydroxybenzoic acid and gpp c synthetic standard of the p hydroxybenzoic acid geranyl ester d negative control divalent cation mgcl final concentrations mm reaction conditions min c chromatographic conditions acn hoac ml min inj vol ll min detection uv k nm s n'},
#  ...]

# %%
entities = pd.DataFrame(data)

# %%
texts = pd.DataFrame(data_2)

# %%
entities
# Out:
#         source_id                                        entity_data  \
# 0               0  {'surface_char_pos': [68, 98], 'surface_form':...
# 1               1  {'surface_char_pos': [0, 13], 'surface_form': ...
# 2               2  {'surface_char_pos': [176, 206], 'surface_form...
# 3              18  {'surface_char_pos': [464, 477], 'surface_form...
# 4              67  {'surface_char_pos': [28, 53], 'surface_form':...
# ...           ...                                                ...
# 100346     684319  {'surface_char_pos': [21, 33], 'surface_form':...
# 100347     684323  {'surface_char_pos': [189, 201], 'surface_form...
# 100348     684341  {'surface_char_pos': [289, 299], 'surface_form...
# 100349     684342  {'surface_char_pos': [416, 428], 'surface_form...
# 100350     684353  {'surface_char_pos': [291, 303], 'surface_form...
#
#                                    uri
# 0       piper crassinervium piperaceae
# 1                        araraquara sp
# 2       piper crassinervium piperaceae
# 3                        araraquara sp
# 4            biotransformation product
# ...                                ...
# 100346                    piperovatine
# 100347                    piperovatine
# 100348                      anesthetic
# 100349                    piperovatine
# 100350                    piperovatine
#
# [100351 rows x 3 columns]

# %%
entities.to_parquet('../kims-bert/CODE/K-BERT/datasets/scholarly_dataset/scholarly__3000__train__entity_mapping_by_sentence.parquet')

# %%
texts.to_csv("../kims-bert/CODE/K-BERT/datasets/scholarly_dataset/scholarly__3000__train.tsv", sep="\t", index=False)

# %%
import pandas as pd
import pickle5 as pickle
from rdkit import Chem
from rdkit.Chem import Descriptors, Crippen

# Create lists to store the SPO triples
spo_triples = []

# Function to add triple if value exists
def add_triple_if_exists(subject, predicate, object_value):
    if pd.notna(object_value) and object_value != "":
        spo_triples.append(f"{subject}\t{predicate}\t{object_value}")

def classify_compound(smiles):
    """Classify compound based on RDKit analysis"""
    try:
        mol = Chem.MolFromSmiles(smiles)
        if mol is None:
            return None

        classifications = {}
        
        # Molecular weight class
        mw = Descriptors.MolWt(mol)
        if mw < 150:
            classifications['weight_class'] = 'small_molecule'
        elif mw < 300:
            classifications['weight_class'] = 'medium_molecule'
        elif mw < 600:
            classifications['weight_class'] = 'large_molecule'
        else:
            classifications['weight_class'] = 'very_large_molecule'

        # Lipinski's Rule of Five
        hbd = Descriptors.NumHDonors(mol)
        hba = Descriptors.NumHAcceptors(mol)
        logp = Crippen.MolLogP(mol)

        if mw <= 500 and hbd <= 5 and hba <= 10 and logp <= 5:
            classifications['drug_likeness'] = 'drug_like'
        else:
            classifications['drug_likeness'] = 'non_drug_like'

        # Aromaticity
        aromatic_atoms = sum(1 for atom in mol.GetAtoms() if atom.GetIsAromatic())
        aromatic_fraction = aromatic_atoms / mol.GetNumAtoms() if mol.GetNumAtoms() > 0 else 0

        if aromatic_fraction > 0.3:
            classifications['aromaticity'] = 'aromatic_rich'
        elif aromatic_fraction > 0:
            classifications['aromaticity'] = 'partially_aromatic'
        else:
            classifications['aromaticity'] = 'aliphatic'

        # Ring systems
        num_rings = len(Chem.GetSSSR(mol))
        if num_rings == 0:
            classifications['ring_type'] = 'acyclic'
        elif num_rings == 1:
            classifications['ring_type'] = 'monocyclic'
        elif num_rings <= 3:
            classifications['ring_type'] = 'polycyclic'
        else:
            classifications['ring_type'] = 'highly_polycyclic'

        return classifications
    except:
        return None

# Process each row in the DataFrame
for _, row in df.iterrows():
    doi = row['doi']

    row['bioActivity'] = re.sub("(\\d|\\W)+", " ", row['bioActivity'])
    row['collectionSpecie'] = re.sub("(\\d|\\W)+", " ", row['collectionSpecie'])
    row['collectionSite'] = re.sub("(\\d|\\W)+", " ", row['collectionSite'])
    row['collectionType'] = re.sub("(\\d|\\W)+", " ", row['collectionType'])

    # Clean and trim each field
    row['bioActivity'] = row['bioActivity'].strip()
    row['collectionSpecie'] = row['collectionSpecie'].strip()
    row['collectionSite'] = row['collectionSite'].strip()
    row['collectionType'] = row['collectionType'].strip()

    # Add triples for each specified relationship
    add_triple_if_exists(row['bioActivity'].lower(), "bioActivity", doi)
    add_triple_if_exists(row['collectionSpecie'].lower(), "collectionSpecie", doi)
    add_triple_if_exists(row['collectionSite'].lower(), "collectionSite", doi)
    add_triple_if_exists(row['collectionType'].lower(), "collectionType", doi)

    # Add triples for chemicals with RDKit enrichment
    if pd.notna(row['smile']) and row['smile'].strip():
        smiles = row['smile'].strip()
        chem_name = row['name'].lower()
        
        # Get RDKit classifications
        classifications = classify_compound(smiles)
        '''if classifications:
            for key, value in classifications.items():
                add_triple_if_exists(chem_name, f"rdkit:{key}", value)'''
        
        # Also add the name-doi relationship
        add_triple_if_exists(chem_name, "name", doi)
    
        
    if ';' in row['name']:
        temp = row['name'].split(';')
        for t in temp:
            t = re.sub("(\\d|\\W)+", " ", t)
            t = t.strip()
            add_triple_if_exists(t.lower(), "name", doi)
            if classifications:
                for key, value in classifications.items():
                    add_triple_if_exists(t.lower(), f"rdkit:{key}", value)
            
    else:
        row['name'] = re.sub("(\\d|\\W)+", " ", row['name'])
        row['name'] = row['name'].strip()
        add_triple_if_exists(row['name'].lower(), "name", doi)
        if classifications:
            for key, value in classifications.items():
                add_triple_if_exists(row['name'].lower(), f"rdkit:{key}", value)

# Write to .spo file
with open('../kims-bert/CODE/K-BERT/brain/kgs/KG_3cols.spo', 'w', encoding='utf-8') as f:
    f.write("sub\tpred\tobj\n")  # Header
    f.write('\n'.join(spo_triples))

print("Knowledge graph has been created in knowledge_graph.spo")
# Out:
# 2026-04-22 19:32:37 - Enabling RDKit 2022.09.5 jupyter extensions
# Knowledge graph has been created in knowledge_graph.spo
